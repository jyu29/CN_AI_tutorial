# %%
# %autosave 300
# %dirs
# Out:
# Autosaving every 300 seconds
# []

# %% [markdown]
# # introduction

# %% [markdown]
# spaCy relies on machine learning models that were trained on a large amount of carefully-labeled texts. These texts were, in fact, often labeled and corrected by hand. This is similar to our topic modeling work from the previous lesson, except our topic model wasn’t using labeled data.
#
# The English-language spaCy model that we’re going to use in this lesson was trained on an annotated corpus called “OntoNotes”: 2 million+ words drawn from “news, broadcast, talk shows, weblogs, usenet newsgroups, and conversational telephone speech,” which were meticulously tagged by a group of researchers and professionals for people’s names and places, for nouns and verbs, for subjects and objects, and much more. Like a lot of other major machine learning projects, OntoNotes was also sponsored by the Defense Advaced Research Projects Agency (DARPA), the branch of the Defense Department that develops technology for the U.S. military.
#
# paCy offers models for other languages including Chinese, German, French, Spanish, Portuguese, Russian, Italian, Dutch, Greek, Norwegian, and Lithuanian.
#
# spaCy offers language and tokenization support for other language via external dependencies — such as PyviKonlpy for Korean.

# %% [markdown]
# __to download language model:__
#
# !python -m spacy download en_core_web_sm
#
#
# notes: spacy.load() does not work

# %% [markdown]
# # import package

# %%
import spacy
import en_core_web_sm
from spacy import displacy
from collections import Counter
import pandas as pd
from pprint import pprint

# %%
import os
os.listdir('data/NYT-Obituaries')
# Out:
# ['1945-Adolf-Hitler.txt',
#  '1915-F-W-Taylor.txt',
#  '1975-Chiang-Kai-shek.txt',
#  '1984-Ethel-Merman.txt',
#  '1953-Jim-Thorpe.txt',
#  '1964-Nella-Larsen.txt',
#  '1955-Margaret-Abbott.txt',
#  '1984-Lillian-Hellman.txt',
#  '1959-Cecil-De-Mille.txt',
#  '1928-Mabel-Craty.txt',
#  '1973-Eddie-Rickenbacker.txt',
#  '1989-Ferdinand-Marcos.txt',
#  '1991-Martha-Graham.txt',
#  '1997-Deng-Xiaoping.txt',
#  '1938-George-E-Hale.txt',
#  '1885-Ulysses-Grant.txt',
#  '1909-Sarah-Orne-Jewett.txt',
#  '1957-Christian-Dior.txt',
#  '1987-Clare-Boothe-Luce.txt',
#  '1976-Jacques-Monod.txt',
#  '1954-Getulio-Vargas.txt',
#  '1979-Stan-Kenton.txt',
#  '1990-Leonard-Bernstein.txt',
#  '1972-Jackie-Robinson.txt',
#  '1998-Fred-W-Friendly.txt',
#  '1991-Leo-Durocher.txt',
#  '1915-B-T-Washington.txt',
#  '1997-James-Stewart.txt',
#  '1981-Joe-Louis.txt',
#  '1983-Muddy-Waters.txt',
#  '1942-George-M-Cohan.txt',
#  '1989-Samuel-Beckett.txt',
#  '1962-Marilyn-Monroe.txt',
#  '2000-Charles-M-Schulz.txt',
#  '1967-Gregory-Pincus.txt',
#  '1894-R-L-Stevenson.txt',
#  '1978-Bruce-Catton.txt',
#  '1982-Arthur-Rubinstein.txt',
#  '1875-Andrew-Johnson.txt',
#  '1974-Charles-Lindbergh.txt',
#  '1964-Rachel-Carson.txt',
#  '1953-Marjorie-Rawlings.txt',
#  '1973-Otto-Klemperer.txt',
#  '1963-Sylvia-Plath.txt',
#  '1956-Charles-Merrill.txt',
#  '1966-Lenny-Bruce.txt',
#  '1908-Cleveland.txt',
#  '1982-Anna-Freud.txt',
#  '1941-Frank-Conrad.txt',
#  '1966-Alfred-P-Sloan-Jr.txt',
#  '1960-Beno-Gutenberg.txt',
#  '1976-J-Paul-Getty.txt',
#  '1891-P-T-Barnum.txt',
#  '1901-Queen-Victoria.txt',
#  '1970-Erich-Maria-Remarque.txt',
#  '1989-August-A-Busch-Jr.txt',
#  '1992-John-Cage.txt',
#  '1994-Erik-Erikson.txt',
#  '1990-Erte.txt',
#  '1966-Chester-Nimitz.txt',
#  '1954-Enrico-Fermi.txt',
#  '1961-Primitive-Artist.txt',
#  '1945-Bela-Bartok.txt',
#  '1978-Pope-Paul-VI.txt',
#  '1965-Martin-Buber.txt',
#  '1971-Diane-Arbus.txt',
#  '1973-Lyndon-Johnson.txt',
#  '1998-Bob-Kane.txt',
#  '1969-Judy-Garland.txt',
#  '1959-Frank-Lloyd-Wright.txt',
#  '1995-Ginger-Rogers.txt',
#  '1920-Marlene-Dietrich.txt',
#  '1998-Alan-B-Shepard-Jr.txt',
#  '1971-Khrushchev.txt',
#  '1935-Justice-Holmes.txt',
#  '1969-David-Eisenhower.txt',
#  '1992-Marsha-P-Johnson.txt',
#  '1914-Alfred-Thayer-Mahan.txt',
#  '1965-Branch-Rickey.txt',
#  '2007-Karen-Sparck-Jones.txt',
#  '1965-Albert-Schweitzer.txt',
#  '1992-Isaac-Asimov.txt',
#  '1989-William-B-Shockley.txt',
#  '1910-William-James.txt',
#  '1951-Fanny-Brice.txt',
#  '1916-Jack-London.txt',
#  '1947-Al-Capone.txt',
#  '1989-Lucille-Ball.txt',
#  '1980-Jean-Paul-Sartre.txt',
#  '1969-Sonja-Henie.txt',
#  '1976-Adolph-Zukor.txt',
#  '1959-John-Dulles.txt',
#  '1980-Alfred-Hitchcock.txt',
#  '1901-Benjamin-Harrison.txt',
#  '1994-Richard-Nixon.txt',
#  '1917-Hilaire-G-E-Degas.txt',
#  '1987-James-Baldwin.txt',
#  '1941-Virginia-Woolf.txt',
#  '1922-Alexander-Graham-Bell.txt',
#  '1907-Qiu-Jin.txt',
#  '1895-Fred-Douglass.txt',
#  '1971-Florence-Blanchfield.txt',
#  '1984-Ray-A-Kroc.txt',
#  '1947-Fiorello-La-Guardia.txt',
#  '1988-Louis-L-Amour.txt',
#  '1902-Elizabeth-Cady-Stanton.txt',
#  '1965-Shirley-Jackson.txt',
#  '1979-John-Wayne.txt',
#  '1994-Thomas-P-O-Neill-Jr.txt',
#  '1982-Thelonious-Monk.txt',
#  '1919-C-J-Walker.txt',
#  '1954-Liberty-H-Bailey.txt',
#  '1977-Dash-Ended.txt',
#  '1936-Maxim-Gorky.txt',
#  '2000-Pierre-Trudeau.txt',
#  '1976-Mao-Tse-Tung.txt',
#  '1955-Walter-White.txt',
#  '1930-Conan-Doyle.txt',
#  '1995-Jonas-Salk.txt',
#  '1949-Mitchell.txt',
#  '1951-Henrietta-Lacks.txt',
#  '1903-James-M-N-Whistler.txt',
#  '1950-A-J-Dempster.txt',
#  '1937-Edith-Wharton.txt',
#  '1935-Jane-Addams.txt',
#  '1941-James-Joyce.txt',
#  '1952-John-Dewey.txt',
#  '1940-Marcus-Garvey.txt',
#  '1971-Louis-Armstrong.txt',
#  '1923-Warren-Harding.txt',
#  '1937-John-Rockefeller.txt',
#  '2000-Elliot-Richardson.txt',
#  '1972-J-Edgar-Hoover.txt',
#  '1975-Franco.txt',
#  '1973-Jeanette-Rankin.txt',
#  '1888-Louisa-M-Alcott.txt',
#  '1977-Charles-Chaplin.txt',
#  '1990-Ralph-David-Abernathy.txt',
#  '1946-Lord-Keynes.txt',
#  '1996-Gene-Kelly.txt',
#  '1973-Roberto-Clemente.txt',
#  '1986-Georgia-O-Keeffe.txt',
#  '1990-Rex-Harrison.txt',
#  '1916-Martian-Theory.txt',
#  '1961-Ernest-Hemingway.txt',
#  '1978-Margaret-Mead.txt',
#  '1982-Ingrid-Bergman.txt',
#  '1946-C-E-M-Clung.txt',
#  '1977-Maria-Callas.txt',
#  '1952-Eva-Peron.txt',
#  '1961-Emily-Balch.txt',
#  '1979-Arthur-Fiedler.txt',
#  '1896-Harriet-Beecher-Stowe.txt',
#  '1989-Andrei-Sakharov.txt',
#  '1939-W-B-Yeats.txt',
#  '1961-Hammarskjold.txt',
#  '1969-Madhubala.txt',
#  '1970-Edouard-Daladier.txt',
#  '1988-John-Houseman.txt',
#  '1992-William-Shawn.txt',
#  '1950-Edna-St-V-Millay.txt',
#  '1989-Claude-Pepper.txt',
#  '1929-Marie-Curie.txt',
#  '1972-The-Duke-of-Windsor.txt',
#  '1984-Count-Basie.txt',
#  '1998-Helen-Moody.txt',
#  '1936-Anne-Macy.txt',
#  '1900-Nietzsche.txt',
#  '1880-Lucretia-Mott.txt',
#  '1967-J-Robert-Oppenheimer.txt',
#  '1984-Richard-Burton.txt',
#  '1964-Sean-O-Casey.txt',
#  '1931-Thomas-Edison.txt',
#  '1971-Bobby-Jones.txt',
#  '1914-John-P-Holland.txt',
#  '1995-George-Abbott.txt',
#  '1950-Henry-L-Stimson.txt',
#  '1955-Dale-Carnegie.txt',
#  '1934-T-A-Watson.txt',
#  '1968-Martin-Luther-King-Jr.txt',
#  '1933-Louis-C-Tiffany.txt',
#  '1909-Geronimo.txt',
#  '1952-Charles-Spaulding.txt',
#  '1922-Nellie-Bly.txt',
#  '1955-Cy-Young.txt',
#  '1993-Arthur-Ashe.txt',
#  '1986-Bernard-Malamud.txt',
#  '1939-Howard-Carter.txt',
#  '1994-Linus-C-Pauling.txt',
#  '1967-Langston-Hughes.txt',
#  '1948-Mohandas-K-Gandhi.txt',
#  '1931-Melvil-Dewey.txt',
#  '1969-Everett-Dirksen.txt',
#  '1968-Helen-Keller.txt',
#  '1992-Alex-Haley.txt',
#  '1953-Eugene-O-Neill.txt',
#  '1981-Anwar-el-Sadat.txt',
#  '1937-Maurice-Ravel.txt',
#  '1966-Margaret-Sanger.txt',
#  '1989-I-F-Stone.txt',
#  '1943-J-H-Kellogg.txt',
#  '1985-Roger-Maris.txt',
#  '1972-Mahalia-Jackson.txt',
#  '1990-Greta-Garbo.txt',
#  '1998-Benjamin-Spock.txt',
#  '1994-Jessica-Tandy.txt',
#  '1979-Richard-Rodgers.txt',
#  '1958-W-C-Handy.txt',
#  '1974-Ed-Sullivan.txt',
#  '1989-Hirohito.txt',
#  '1933-Calvin-Coolidge.txt',
#  '1969-Ho-Chi-Minh.txt',
#  '1987-John-Huston.txt',
#  '1984-Johnny-Weissmuller.txt',
#  '1969-Maureen-Connolly.txt',
#  '1968-Yuri-Gagarin.txt',
#  '1991-Peggy-Ashcroft.txt',
#  '1979-A-Philip-Randolph.txt',
#  '1946-Gertrude-Stein.txt',
#  '1993-Thurgood-Marshall.txt',
#  '1887-Emma-Lazarus.txt',
#  '1986-James-Cagney.txt',
#  '1976-Richard-Daley.txt',
#  '1977-Joan-Crawford.txt',
#  '1971-Hugo-Black.txt',
#  '1954-Henri-Matisse.txt',
#  '1906-Susan-B-Anthony.txt',
#  '1990-Sammy-Davis-Jr.txt',
#  '1914-John-Muir.txt',
#  '1954-Anne-O-Hare-McCormick.txt',
#  '1986-Kate-Smith.txt',
#  '1919-Anna-H-Shaw.txt',
#  '1980-Jean-Piaget.txt',
#  '1966-Buster-Keaton.txt',
#  '1997-Allen-Ginsberg.txt',
#  '1991-Miles-Davis.txt',
#  '1982-Satchel-Paige.txt',
#  '1931-Ida-B-Wells.txt',
#  '1967-Henry-R-Luce.txt',
#  '1984-Ansel-Adams.txt',
#  '1945-Ernie-Pyle.txt',
#  '1952-Chaim-Weizmann.txt',
#  '1973-Nancy-Mitford.txt',
#  '1852-Ada-Lovelace.txt',
#  '1996-Timothy-Leary.txt',
#  '1919-Carnegie-Started.txt',
#  '1989-Andrei-A-Gromyko.txt',
#  '1965-David-O-Selznick.txt',
#  '1870-Robert-E-Lee.txt',
#  '1968-Robert-Francis-Kennedy.txt',
#  '1900-Stephen-Crane.txt',
#  '1936-John-W-Heisman.txt',
#  '1998-Maureen-O-Sullivan.txt',
#  '1953-Joseph-Stalin.txt',
#  '1944-Alfred-E-Smith.txt',
#  '1910-Tolstoy.txt',
#  '1964-Cole-Porter.txt',
#  '1983-Jack-Dempsey.txt',
#  '1975-Haile-Selassie.txt',
#  '1882-Charles-Darwin.txt',
#  '1903-Emily-Warren-Roebling.txt',
#  '1962-Eleanor-Roosevelt.txt',
#  '1926-Harry-Houdini.txt',
#  '1955-Albert-Einstein.txt',
#  '1971-Coco-Chanel.txt',
#  '1959-Billie-Holiday.txt',
#  '1969-Coleman-Hawkins.txt',
#  '1954-Frida-Kahlo.txt',
#  '1911-Joseph-Pulitzer.txt',
#  '1993-Carlos-Montoya.txt',
#  '1947-Max-Planck.txt',
#  '1985-Orson-Welles.txt',
#  '1974-Earl-Warren.txt',
#  '1971-Ralph-Bunche.txt',
#  '1999-Hassan-II.txt',
#  '1931-Knute-Rocke.txt',
#  '1998-Theodore-Schultz.txt',
#  '1960-Boris-Pasternak.txt',
#  '1927-Victoria-Martin.txt',
#  '1943-George-Washington-Carver.txt',
#  '1956-Thomas-J-Watson-Sr.txt',
#  '1947-Henry-Ford.txt',
#  '1953-Fred-Vinson.txt',
#  '1982-Leonid-Brezhnev.txt',
#  '1999-King-Hussein.txt',
#  '1930-Elmer-Sperry.txt',
#  '1985-E-B-White.txt',
#  '1959-Ethel-Barrymore.txt',
#  '.ipynb_checkpoints',
#  '1986-Benny-Goodman.txt',
#  '1963-W-E-B-DuBois.txt',
#  '1975-Elijah-Muhammad.txt',
#  '1973-Pablo-Picasso.txt',
#  '1993-Federico-Fellini.txt',
#  '1945-Harry-S-Truman.txt',
#  '1970-De-Gaulle-Rallied.txt',
#  '1995-Alfred-Eisenstaedt.txt',
#  '1999-Iris-Murdoch.txt',
#  '1987-Alf-Landon.txt',
#  '1998-Bella-Abzug.txt',
#  '1940-Scott-Fitzgerald.txt',
#  '1989-Vladimir-Horowitz.txt',
#  '1969-Mies-van-der-Rohe.txt',
#  '1944-Ida-M-Tarbell.txt',
#  '1948-John-Pershing.txt',
#  '1938-Clarence-Darrow.txt',
#  '1987-Primo-Levi.txt',
#  '1971-Igor-Stravinsky.txt',
#  '1945-George-Patton.txt',
#  '1930-William-Howard-Taft.txt',
#  '1935-Will-Rogers.txt',
#  '1992-Shirley-Booth.txt',
#  '1994-Jacqueline-Kennedy.txt',
#  '1933-Ring-Lardner.txt',
#  '1974-Sylvia-Plath.txt',
#  '1945-FDR.txt',
#  '1995-Yitzhak-Rabin.txt',
#  '1960-Emily-Post.txt',
#  '1984-Truman-Capote.txt',
#  '1968-Upton-Sinclair.txt',
#  '1994-Jan-Tinbergen.txt',
#  '1957-Gerard-Swope.txt',
#  '1993-Albert-Sabin.txt',
#  '1955-Thomas-Mann.txt',
#  '1991-Dr-Seuss.txt',
#  '1877-Bedford-Forrest.txt',
#  '1964-Douglas-MacArthur.txt',
#  '1965-Churchill.txt',
#  '1962-William-Faulkner.txt',
#  '1956-Babe-Zaharias.txt',
#  '1932-John-Philip-Sousa.txt',
#  '1964-Herbert-Hoover.txt',
#  '1961-Sam-Rayburn.txt',
#  '1954-Lionel-Barrymore.txt',
#  '1998-Frank-Sinatra.txt',
#  '1948-Babe-Ruth.txt',
#  '1947-Willa-Cather.txt',
#  '1963-John-F-Kennedy.txt',
#  '1975-Walker-Evans.txt',
#  '1916-J-J-Hill.txt',
#  '1980-Jesse-Owens.txt',
#  '1948-Sergei-Eisenstein.txt',
#  '1981-Robert-Moses.txt',
#  '1989-Robert-Penn-Warren.txt',
#  '1901-William-McKinley.txt',
#  '1970-Walter-Reuther.txt',
#  '1930-Balfour.txt',
#  '1984-Indira-Gandhi.txt',
#  '1978-Golda-Meir.txt',
#  '1983-Earl-Hines.txt',
#  '1974-Katharine-Cornell.txt',
#  '1982-Lee-Strasberg.txt',
#  '1939-Pope-Pius-XI.txt',
#  '1886-Mary-Ewing-Outerbridge.txt',
#  '1993-Dizzy-Gillespie.txt',
#  '1993-Dizzy-Gillespie.txt',
#  '1910-Florence-Nightingale.txt',
#  '1960-Richard-Wright.txt',
#  '1986-The-Challenger.txt',
#  '1992-Menachem-Begin.txt',
#  '1998-Galina-Ulanova.txt',
#  '1976-Max-Ernst.txt',
#  '1993-Cesar-Chavez.txt',
#  '1965-Adlai-Ewing-Stevenson.txt',
#  '1935-Adolph-S-Ochs.txt',
#  '1941-Lou-Gehrig.txt',
#  '1961-Carl-G-Jung.txt',
#  '1963-Robert-Frost.txt',
#  '1965-Edward-R-Murrow.txt',
#  '1971-Dean-Acheson.txt',
#  '1986-Jorge-Luis-Borges.txt',
#  '1966-Walt-Disney.txt',
#  '1996-Carl-Sagan.txt',
#  '1959-Ross-G-Harrison.txt',
#  '1945-Jerome-Kern.txt',
#  '1991-Frank-Capra.txt',
#  '1987-Andres-Segovie.txt',
#  '1987-Rita-Hayworth.txt',
#  '1993-William-Golding.txt',
#  '1932-Florenz-Ziegfeld.txt',
#  '1938-Constantin-Stanislavsky.txt']

# %% [markdown]
# # basics

# %%
filepath = "data/NYT-Obituaries/1945-Adolf-Hitler.txt"
text = open(filepath, encoding='utf-8').read()

# %%
nlp = en_core_web_sm.load()

# %%
document = nlp(text)

# %%
# count of how many entity
len(document.ents)
# Out:
# 17

# %%
# details of entity recongized in the document
[x.label_ for x in document.ents]
# Out:
# ['ORG',
#  'GPE',
#  'NORP',
#  'GPE',
#  'GPE',
#  'GPE',
#  'DATE',
#  'ORG',
#  'PERSON',
#  'PERSON',
#  'PERSON',
#  'PERSON',
#  'GPE',
#  'NORP',
#  'LOC',
#  'ORG',
#  'GPE']

# %%
displacy.render(document, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     May 2, 1945
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br></br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     OBITUARY
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br></br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hitler Fought Way
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  to Power Unique in Modern History</br></br> BY THE NEW YORK TIMES</br></br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Adolf Hitler
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# -time
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Austrian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  vagabond who rose to be the dictator of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Germany
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , &quot;augmenter of the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reich
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# &quot; and the scourge of
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Europe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , was, like
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lenin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mussolini
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , a product of the First World</br></br> War. The same general circumstances, born of the titanic conflict, that carried
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lenin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , a bookish professional revolutionist, to the pinnacle of power in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Empire of the Czars
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and cleared the road to mastery for
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mussolini
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rome
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  of the Caesars also paved the way for
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hitler
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# 's domination in the former mighty
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Germany
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  of the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hohenzollerns
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# .</br></br> Like
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lenin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mussolini
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hitler
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  came out of the blood and chaos of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1914-18
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , but of the
# <mark class

# %% [markdown]
# # spacy named entity
#
# Each of the named entities in document.ents contains more information about itself, which we can access by iterating through the document.ents with a simple for loop.
#
# <table>
#   <tr><td>
#     <img src="https://miro.medium.com/max/1400/1*qQggIPMugLcy-ndJ8X_aAA.png"
#          alt="Fashion MNIST sprite"  width="600">
#   </td></tr>

# %%
document.ents
# Out:
# (May 2, 1945,
#  OBITUARY,
#  Hitler Fought Way,
#  Adolf Hitler,
#  one,
#  Austrian,
#  Germany,
#  Reich,
#  Europe,
#  Lenin,
#  Mussolini,
#  Lenin,
#  the Empire of the Czars,
#  Mussolini,
#  Rome,
#  Hitler,
#  Germany,
#  Hohenzollerns,
#  Lenin,
#  Mussolini,
#  Hitler,
#  1914-18,
#  three,
#  Lenin,
#  the Russian Revolution,
#  Mussolini,
#  Socialist,
#  Hitler,
#  Germans,
#  world revolution,
#  Mussolini,
#  Hitler,
#  1918,
#  Germany,
#  supreme Fuehrer,
#  nine,
#  Europe,
#  millions,
#  Germans,
#  Fatherland,
#  Austria,
#  7,000,000,
#  More than 2,000,000,
#  Germans,
#  Sudeten,
#  Czechoslovakia,
#  10,000,000,
#  Czechs,
#  Slovaks,
#  State,
#  Central Europe,
#  Nazi,
#  more than six years,
#  January, 1933,
#  Hitler,
#  Poland,
#  Anglo,
#  Czechoslovakia Hitler,
#  Poland,
#  France,
#  England,
#  less than a year later,
#  Europe,
#  one,
#  "Mein Kampf",
#  Czechoslovakia,
#  Munich,
#  Prague,
#  German,
#  first,
#  June, 1934,
#  Ernst Roehm,
#  Nazis,
#  Nazi,
#  thousands,
#  Jews,
#  Catholic,
#  Nazis,
#  Hitler,
#  Hitler,
#  these Pastor Niemoeller,
#  Niemoeller,
#  Christianity,
#  Nazi,
#  State,
#  Germany,
#  nearly fifteen years,
#  Hitler,
#  1933,
#  Germans,
#  Nazis,
#  Hitler,
#  Hitler,
#  over millions,
#  Aryan,
#  Max von
#
#   Gruber,
#  German,
#  Hitler,
#  first,
#  German,
#  1923,
#  one,
#  one,
#  Hitler,
#  first,
#  Mein Kampf,
#  Jews,
#  Hitler,
#  Hitler,
#  Braynau,
#  Austria,
#  German,
#  April 20, 1889,
#  Alois Schickelgruber,
#  Alois Hitler,
#  Fuehrer,
#  Austrian,
#  three,
#  third,
#  twenty years,
#  Seven,
#  three,
#  Hitler,
#  the age of 66,
#  three,
#  Two,
#  Hitler,
#  Fuehrer,
#  half,
#  German,
#  the age of 16,
#  Austro,
#  Adolf Hitler,
#  Germany,
#  Germans,
#  Austrians,
#  Franz Josef's,
#  Hitler,
#  the age of 14,
#  Hitler,
#  Linz,
#  19,
#  Hitler,
#  Munich,
#  Vienna,
#  the Academy of Arts,
#  1909,
#  the First World War,
#  Hitler,
#  Vienna,
#  nights,
#  three years,
#  twenty-fifth year,
#  Hitler,
#  those days,
#  the First World War Hitler,
#  one,
#  the Austro- Hungarian Empire,
#  German,
#  Slavs,
#  Jews,
#  Otto Strasser,
#  Nazi,
#  1930,
#  Germans,
#  Jews,
#  Own Basic Principles Governing Society,
#  Economics,
#  Hitler,
#  Nazi,
#  Nazi,
#  Fuehrer,
#  Germans,
#  Reich,
#  Polish,
#  August, 1939,
#  Vienna,
#  1913,
#  Munich,
#  Viennese,
#  Hitler,
#  Hitler,
#  those hours,
#  Hitler,
#  Mein Kampf,
#  A year before,
#  Salzburg,
#  Austrian,
#  the German Army,
#  the Iron Cross,
#  some day,
#  Passewalk,
#  Pomerania,
#  the German Empire,
#  hour,
#  Kaiser,
#  his day,
#  Hitler,
#  Reichswehr,
#  Reichswehr,
#  the German Republic,
#  Putsches,
#  Kapp,
#  August, 1920,
#  Berlin,
#  the Ebert Government,
#  the Interallied Military Commission,
#  Germany,
#  Versailles,
#  German Labor Party',
#  1919,
#  Hitler,
#  Reichswehr,
#  Communist,
#  Bavaria,
#  1919,
#  Hitler,
#  Communists,
#  Socialists,
#  republican,
#  1919 Hitler,
#  the German Labor party,
#  Hitler,
#  several hundred,
#  Ernst Roehm,
#  Bavaria,
#  the German National Socialist party,
#  Hitler,
#  Hitler,
#  the German Labor party,
#  Dietrich Eckhart,
#  Nazis,
#  Eckhart,
#  1923,
#  Hitler,
#  the German Labor party,
#  Rudolph Hess,
#  Deputy Fuehrer,
#  second,
#  Hitler,
#  Poland,
#  1939,
#  Alfred Rosenberg,
#  Nazi,
#  1941,
#  only six,
#  German,
#  Hitler,
#  These half dozen,
#  Hitler,
#  second,
#  Hitler,
#  Germany,
#  first,
#  Germany,
#  four-year,
#  many decades,
#  Hitler,
#  first,
#  Germans,
#  Germany,
#  1928,
#  1932,
#  Germany,
#  Hitler,
#  Germany,
#  Hitler,
#  Hitler,
#  Hitler,
#  Germany,
#  the Versailles Treaty,
#  Communists,
#  Goebbels,
#  Hitler,
#  Propaganda and Enlightenment,
#  later years,
#  Propaganda,
#  Marxist,
#  1923,
#  Treason,
#  Hitler,
#  those early years,
#  Army,
#  Hitler,
#  first,
#  Nov. 8 and 9, 1923,
#  Munich,
#  Putsch,
#  Hitler,
#  Bavarian,
#  Ministers, Government,
#  the Munich City Hall,
#  the evening of Nov. 8,
#  Berlin,
#  Hitler,
#  General Ludendorff,
#  Hitler,
#  Bavarian,
#  von Kahr,
#  von Lossow,
#  the Bavarian Army,
#  State,
#  State,
#  next day,
#  between several thousand,
#  Hitler,
#  Lossow,
#  Hitler,
#  Ludendorff,
#  Ludendorff,
#  Hitler,
#  thousands,
#  Nazis,
#  Ludendorff,
#  Hitler,
#  Hitler,
#  first,
#  five years',
#  only a few months,
#  Defeat
#
#   ,
#  Munich,
#  Hitler,
#  Hitler,
#  Mein Kampf,
#  the next seven years,
#  3,000,000,
#  army corps,
#  army,
#  the Storm Troops,
#  the Black Guards,
#  Hitler,
#  Jews,
#  Munich,
#  Communists,
#  republicans,
#  Nazi,
#  Socialists,
#  Democrats,
#  Reichsbanner,
#  Communists,
#  Socialists,
#  republicans,
#  Red-Front Fighters
#
#   League,
#  Bavaria,
#  Thuringia,
#  German,
#  Hitlerites,
#  Prussia,
#  Hitler,
#  Nazis,
#  Germany,
#  millions,
#  the
#
#   Government,
#  Gustav Stresemann,
#  Socialists,
#  Democrats,
#  Joseph Goebbels,
#  Captain Roehm,
#  Hitler,
#  Reichswehr,
#  millions,
#  Reichswehr,
#  Germany,
#  Hitler,
#  those days,
#  five years,
#  von Schleicher,
#  the years,
#  Munich,
#  1930,
#  Hitler,
#  Germany,
#  Reichstag,
#  that year,
#  Hitler,
#  1930,
#  6,000,000,
#  107,
#  struggling German Republic,
#  Hitler,
#  Nazi,
#  1929,
#  Germany,
#  Nearly 7,000,000,
#  the millions,
#  the hundreds of thousands,
#  Hitler,
#  Hitlerism,
#  the democratic republic,
#  Red and Brown,
#  Reichstag,
#  Prussian,
#  Legislatures,
#  republican,
#  1932,
#  Hitlerites,
#  Communists,
#  Berlin,
#  1930,
#  Hitler,
#  Reichswehr,
#  three,
#  Reichswehr,
#  Hitler,
#  November,
#  German,
#  the Weimar Republic,
#  Hitler,
#  Germany,
#  Heinrich Bruening,
#  Centrist,
#  many months,
#  Hitler,
#  1931,
#  Hitler,
#  von Hindenburg,
#  first,
#  Hitler,
#  Hitler,
#  Bruening,
#  Nazis,
#  Hitler,
#  Hindenburg,
#  the spring of 1932,
#  the Versailles Treaty,
#  Nazis,
#  Hindenburg,
#  third,
#  19,000,000,
#  13,000,000,
#  Hitler,
#  Hitler,
#  Reichstag,
#  July 31, 1932,
#  Nazis,
#  229,
#  the end of the year,
#  Hitler,
#  Chancellorship,
#  Hindenburg,
#  Hindenburg,
#  Cabinet,
#  Reichstag,
#  Nov. 6, 1932,
#  Hitlerites,
#  2,000,000,
#  Nazi,
#  Hitler,
#  Franz von Papen,
#  Catholic,
#  the United
#
#   States,
#  the First World War,
#  Von Papen's,
#  the Cabinet of monocles,
#  von Schleicher,
#  army,
#  Hitlerites,
#  Communists,
#  von Papen's,
#  Chancellorship,
#  Von Schleicher's,
#  second,
#  von Papen,
#  bent,
#  Hitler,
#  von Schleicher,
#  Reichstag,
#  Hindenburg,
#  Oskar,
#  von Blomberg,
#  Hitler,
#  Hitler,
#  Schleicher,
#  Jan. 30, 1933,
#  Hitler,
#  Hitler,
#  Hindenburg,
#  Constitution,
#  Reichstag,
#  Hitler,
#  Hindenburg,
#  Hitler,
#  Reichstag,
#  Nazis,
#  the National Treasury,
#  Nazis,
#  Nationalists,
#  Hugenberg,
#  Reichstag,
#  Hitler,
#  Nazi,
#  The Burning of the Reichstag
#
#   One of the,
#  Nazi,
#  the evening of Feb. 27, 1933,
#  a week,
#  that evening,
#  Hitler,
#  Communists,
#  Reichstag,
#  Communists,
#  Hitler,
#  a week later,
#  only 43 percent,
#  the Nazi Government,
#  Communists,
#  German,
#  Communist,
#  Torgler,
#  the Bulgarian Communist,
#  the Communist International,
#  Marinus van der Lubbe,
#  Dutch Communist,
#  the Reichstag Building,
#  Germany,
#  Hitlerites,
#  Reichstag,
#  Hitler,
#  Goering,
#  Prussia,
#  Communist,
#  Social Democrats,
#  Reichstag,
#  March 23,
#  Reichstag,
#  the Kroll Opera House,
#  Hitler,
#  Social Democrats,
#  Hitler,
#  Germany,
#  June 27,
#  Hugenberg,
#  Conservatives,
#  Government,
#  Nazis,
#  Hitler,
#  Reichstag,
#  four years,
#  April 1, 1937,
#  Germany,
#  March 12, 1933,
#  von Hindenburg,
#  Nazi,
#  Hitler,
#  Germany,
#  millions,
#  Hitler,
#  Socialist,
#  Communist,
#  Democratic,
#  Republicans,
#  Nationalist,
#  the Centrist party,
#  German Catholics,
#  Unity of Nazi Party,
#  State,
#  Socialists,
#  Communists,
#  Catholics,
#  Germany,
#  anti-Semitic,
#  Jews,
#  Nuremberg,
#  April 1, 1933,
#  Nazis,
#  one-day,
#  Jewish,
#  Jews,
#  German,
#  Jews,
#  Gentiles,
#  Germany,
#  Hitler,
#  One,
#  Hitler,
#  German,
#  Berlin,
#  Nazi,
#  Germany,
#  Nazis,
#  Nazi,
#  Germany,
#  Western,
#  Dec. 1, 1933,
#  Nazi,
#  State,
#  Hitler,
#  Nazis,
#  State,
#  Captain Roehm,
#  Hitler,
#  State,
#  the Storm Troopers,
#  Nazi,
#  one,
#  Nazi,
#  Hitler,
#  the days,
#  the Storm Troopers,
#  Roehm,
#  Reichswehr,
#  Hitler,
#  June, 1934,
#  the Storm Troop,
#  a month,
#  July 1,
#  Roehm,
#  June 30,
#  the following day Roehm,
#  Hitler,
#  Roehm,
#  von Schleicher,
#  July 13,
#  Hitler,
#  German,
#  seventy-seven,
#  1,000,
#  Aug. 2, 1934,
#  von Hindenburg,
#  Neudeck, Prussia,
#  a few hours,
#  Hitler,
#  German,
#  Fuehrer,
#  Aug. 19,
#  Hitler,
#  Germany,
#  Rhineland,
#  Austria,
#  Czechoslovakia,
#  Memel,
#  Polish,
#  Corridor,
#  Poland,
#  Denmark,
#  Norway,
#  Holland,
#  Belgium,
#  Luxembourg,
#  France,
#  Balkans,
#  Russia,
#  the European Continent,
#  Nazi,
#  Germany,
#  Napoleon,
#  Hitler,
#  Allied,
#  Germany,
#  Hitler,
#  Intuition' Strategy Helped Hasten Defeat of,
#  Germany,
#  East,
#  Hitler,
#  France,
#  England,
#  Germany,
#  German,
#  Rhineland,
#  Austria,
#  Czechoslovak,
#  1938,
#  Poland,
#  Hitler,
#  Britain,
#  France,
#  Munich,
#  Poland,
#  first,
#  German,
#  the early years,
#  France,
#  June, 1940,
#  Paris,
#  Russia,
#  June, 1940,
#  Germans,
#  Russia,
#  Less than two years later,
#  Russia,
#  Germany,
#  a few months,
#  Russia,
#  German,
#  Moscow,
#  German,
#  Field Marshal,
#  Russia,
#  one,
#  German,
#  300,000,
#  Stalingrad,
#  February, 1943,
#  Hitler,
#  German,
#  the United States,
#  Japan,
#  Italy,
#  Dec. 11, 1941,
#  another fateful day,
#  Russia,
#  Russia,
#  the United States,
#  Europe,
#  the United States,
#  Pacific,
#  European,
#  Japan,
#  Russia,
#  Germany,
#  Russia,
#  a few weeks,
#  months,
#  Japan,
#  Germany,
#  Hitler,
#  Allies,
#  French,
#  North Africa,
#  November, 1942,
#  Italy,
#  Mussolini,
#  German,
#  Italian,
#  Axis,
#  Italy,
#  September of that year,
#  Mussolini,
#  Allies,
#  Hitler,
#  Mussolini,
#  Italy,
#  Italian,
#  Anglo-American,
#  April 28, 1945,
#  Mussolini,
#  Italian,
#  Partisans,
#  Hitler,
#  Berlin,
#  Hitler,
#  Germany,
#  Allies,
#  Hitler,
#  Allies,
#  Normandy,
#  June 6, 1944,
#  the middle of 1944,
#  German,
#  Hitler,
#  July 20, 1944,
#  Hundreds,
#  Hitler,
#  the last few weeks,
#  Munich,
#  Sudeten,
#  Germany,
#  the end of September, 1938,
#  the Czechoslovak State,
#  Europe,
#  the end of the First World War,
#  France,
#  England,
#  Sudeten,
#  Hitler,
#  Czechoslovakia,
#  less than six months later,
#  Poland,
#  the United States,
#  Sudeten,
#  months,
#  the Sudeten Nazis,
#  Konrad Henlein,
#  Henleinists,
#  the Czechoslovak State,
#  Berlin,
#  Prague,
#  European,
#  Great Britain,
#  Runciman,
#  Czechoslovakia,
#  German,
#  many weeks,
#  Henleinists,
#  Sudeten,
#  Germany,
#  Henleinists,
#  Runciman,
#  Sudeten,
#  Czechoslovakia,
#  Nuremberg,
#  Hitler,
#  Sudetens,
#  Czechoslovakia,
#  Germany,
#  Sept. 14,
#  German,
#  Czech,
#  Hitler,
#  British,
#  Neville Chamberlain,
#  Berchtesgaden,
#  Hitler,
#  Czechoslovakia,
#  England,
#  France,
#  Germany,
#  London,
#  Chamberlain,
#  the House of Commons,
#  Europe,
#  Hitler,
#  Sudeten,
#  Germany,
#  French,
#  British,
#  Czechoslovakia,
#  Chamberlain,
#  Germany,
#  Hitler,
#  Godesberg,
#  Chamberlain,
#  Hitler,
#  French,
#  British,
#  Chamberlain,
#  Hitler,
#  Czechoslovakia,
#  Oct. 1,
#  Hitler,
#  Czechoslovakia,
#  Munich,
#  Hitler,
#  Sept. 29,
#  the next few days,
#  Munich,
#  German,
#  Sudeten,
#  Czechs,
#  One,
#  Munich,
#  the Czechoslovak Government,
#  Eduard Benes,
#  Czechoslovakia,
#  Slovakia,
#  Hlinka,
#  Hlinka Guards,
#  Nazi,
#  German,
#  Slovaks,
#  March, 1939,
#  the Prague Government,
#  Slovak,
#  Slovak,
#  Tiso,
#  Germany,
#  Hitler,
#  March 12,
#  anti-Czech,
#  German,
#  Bratislava,
#  Slovak,
#  German,
#  Czechs,
#  Tiso,
#  Czechs,
#  Berlin,
#  Hitler,
#  German,
#  Czech,
#  March 13,
#  Hitler,
#  Hacha,
#  Czechoslovakia,
#  Slovak,
#  Bratislava,
#  Slovakia,
#  Slovaks,
#  Czechoslovakia,
#  Hungary,
#  the Carpatho-Ukraine,
#  March 14,
#  Berlin,
#  Hacha,
#  Frantisek Chvalkovsky,
#  Hitler,
#  Hitler,
#  three hours,
#  Hacha,
#  Czech,
#  Reich,
#  German,
#  Bohemia,
#  Czechs,
#  Prague,
#  Hitler,
#  Czechoslovakia,
#  the morning of the same day,
#  German,
#  Prague,
#  Gestapo,
#  German,
#  the National Bank,
#  the late afternoon,
#  Czech,
#  the Hradschin Castle,
#  Bohemian,
#  Habsburgs,
#  Czech,
#  March 15,
#  Moravia,
#  Bohemia,
#  Reich,
#  German,
#  Hitler,
#  Jews,
#  Hradschin,
#  Hitler,
#  Bohemia,
#  Moravia,
#  German,
#  many centuries ago,
#  the Holy Roman Empire,
#  Germany,
#  Slovakia,
#  Germany,
#  Hitler,
#  Czechoslovakia,
#  German,
#  Reich,
#  the Carpatho-Ukraine,
#  Hungary,
#  Poland,
#  Hitler,
#  Nazis,
#  Budapest,
#  Hungary,
#  Czechoslovakia,
#  March 16,
#  Bohemia,
#  Moravia,
#  Hitler,
#  Vienna,
#  Prague,
#  Czechoslovak,
#  Gestapo,
#  several thousand,
#  Jews,
#  Austria,
#  Sudeten,
#  March 18,
#  Hitler,
#  the "Reich Protector",
#  Bohemia,
#  Moravia,
#  Konstantin von Neurath,
#  Nazi,
#  Nazi,
#  Cabinet Council,
#  6 Months,
#  Threats
#
#   Browbeating,
#  Corridor,
#  March, 1939,
#  Charges of 'Oppression',
#  Reich Nationals
#
#   ,
#  Polish,
#  second,
#  World War,
#  Hitler,
#  Czechoslovakia,
#  Sudeten,
#  September, 1938,
#  Poles,
#  Hitler,
#  Polish,
#  Jan. 26, 1934,
#  ten years,
#  Poland,
#  France,
#  Polish,
#  Germany,
#  France,
#  Poland,
#  two,
#  Sept. 23, 1938,
#  Hitler,
#  Berlin,
#  Germany,
#  Europe,
#  Poland,
#  1934,
#  Warsaw,
#  November,
#  January, 1939,
#  the Pact of Warsaw,
#  Reichstag,
#  that month,
#  Joseph Beck,
#  Poland,
#  Berchtesgaden,
#  two,
#  ...)

# %% [markdown]
# For each named_entity in document.ents, we will extract the named_entity and its corresponding ^named_entity.label_.

# %%
# for named_entity in document.ents:
#     print(named_entity, named_entity.label_)


pprint([(x.text,x.label_) for x in document.ents])
# Out:
# [('Palace', 'ORG'),
#  ('Berlin', 'GPE'),
#  ('Nordic', 'NORP'),
#  ('Wotan', 'GPE'),
#  ('Favorite City', 'GPE'),
#  ('Munich', 'GPE'),
#  ('1935', 'DATE'),
#  ('Prinzregentenstrasse', 'ORG'),
#  ('Frau Angella Raubal', 'PERSON'),
#  ('Martin Hammisch', 'PERSON'),
#  ('Haus Wachenfeld', 'PERSON'),
#  ('Hitler', 'PERSON'),
#  ('Berchtesgaden', 'GPE'),
#  ('Bavarian', 'NORP'),
#  ('Alps', 'LOC'),
#  ('Fuehrer', 'ORG'),
#  ('Austria', 'GPE')]

# %%
import math

number_of_chunks = 80

chunk_size = math.ceil(len(text) / number_of_chunks)

text_chunks = []

for number in range(0, len(text), chunk_size):
    text_chunk = text[number:number+chunk_size]
    text_chunks.append(text_chunk)

# %%
chunked_documents = list(nlp.pipe(text_chunks))

# %% [markdown]
# ## to pandas

# %%
org = []

# for named_entity in document.ents:
#     print(named_entity, named_entity.label_)

for document in chunked_documents:
    for named_entity in document.ents:
        if named_entity.label_ == "ORG":
            org.append(named_entity.text)

people_tally = Counter(org)

df = pd.DataFrame(people_tally.most_common(), columns=['character', 'count'])

# %%
df
# Out:
#                character  count
# 0                  State      8
# 1                Fuehrer      5
# 2              Reichstag      5
# 3             Hindenburg      3
# 4         the Iron Cross      2
# ..                   ...    ...
# 83      Siegfried Wagner      1
# 84          neurasthenia      1
# 85    the Vienna Academy      1
# 86   the Brown\n\n House      1
# 87  Prinzregentenstrasse      1
#
# [88 rows x 2 columns]

# %% [markdown]
# # spacy tokens

# %% [markdown]
# During the above example, we were working on entity level, in the following example, we are demonstrating token-level entity annotation using the BILUO tagging scheme to describe the entity boundaries.
#
# - "B" means the token begins an entity
# - "I" means it is inside an entity,
# - "O" means it is outside an entity, and "" means no entity tag is set.
#
# <table>
#   <tr><td>
#     <img src="https://miro.medium.com/max/1400/1*_sYTlDj2p_p-pcSRK25h-Q.png"
#          alt="Fashion MNIST sprite"  width="600">
#   </td></tr>

# %%
pprint([(x,x.ent_iob_,x.ent_type_)for x in document])
# Out:
# [(May, 'B', 'DATE'),
#  (2, 'I', 'DATE'),
#  (,, 'I', 'DATE'),
#  (1945, 'I', 'DATE'),
#  (
#
#  , 'O', ''),
#  (OBITUARY, 'B', 'ORG'),
#  (
#
#  , 'O', ''),
#  (Hitler, 'B', 'PERSON'),
#  (Fought, 'I', 'PERSON'),
#  (Way, 'I', 'PERSON'),
#  (to, 'O', ''),
#  (Power, 'O', ''),
#  (Unique, 'O', ''),
#  (in, 'O', ''),
#  (Modern, 'O', ''),
#  (History, 'O', ''),
#  (
#
#  , 'O', ''),
#  (BY, 'O', ''),
#  (THE, 'O', ''),
#  (NEW, 'O', ''),
#  (YORK, 'O', ''),
#  (TIMES, 'O', ''),
#  (
#
#  , 'O', ''),
#  (Adolf, 'B', 'PERSON'),
#  (Hitler, 'I', 'PERSON'),
#  (,, 'O', ''),
#  (one, 'B', 'CARDINAL'),
#  (-, 'O', ''),
#  (time, 'O', ''),
#  (Austrian, 'B', 'NORP'),
#  (vagabond, 'O', ''),
#  (who, 'O', ''),
#  (rose, 'O', ''),
#  (to, 'O', ''),
#  (be, 'O', ''),
#  (the, 'O', ''),
#  (dictator, 'O', ''),
#  (of, 'O', ''),
#  (Germany, 'B', 'GPE'),
#  (,, 'O', ''),
#  (", 'O', ''),
#  (augmenter, 'O', ''),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (Reich, 'B', 'PERSON'),
#  (", 'O', ''),
#  (and, 'O', ''),
#  (the, 'O', ''),
#  (scourge, 'O', ''),
#  (of, 'O', ''),
#  (Europe, 'B', 'LOC'),
#  (,, 'O', ''),
#  (was, 'O', ''),
#  (,, 'O', ''),
#  (like, 'O', ''),
#  (Lenin, 'B', 'PERSON'),
#  (and, 'O', ''),
#  (Mussolini, 'B', 'PERSON'),
#  (,, 'O', ''),
#  (a, 'O', ''),
#  (product, 'O', ''),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (First, 'O', ''),
#  (World, 'O', ''),
#  (
#
#  , 'O', ''),
#  (War, 'O', ''),
#  (., 'O', ''),
#  (The, 'O', ''),
#  (same, 'O', ''),
#  (general, 'O', ''),
#  (circumstances, 'O', ''),
#  (,, 'O', ''),
#  (born, 'O', ''),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (titanic, 'O', ''),
#  (conflict, 'O', ''),
#  (,, 'O', ''),
#  (that, 'O', ''),
#  (carried, 'O', ''),
#  (Lenin, 'B', 'PERSON'),
#  (,, 'O', ''),
#  (a, 'O', ''),
#  (bookish, 'O', ''),
#  (professional, 'O', ''),
#  (revolutionist, 'O', ''),
#  (,, 'O', ''),
#  (to, 'O', ''),
#  (the, 'O', ''),
#  (pinnacle, 'O', ''),
#  (of, 'O', ''),
#  (power, 'O', ''),
#  (in, 'O', ''),
#  (the, 'B', 'GPE'),
#  (Empire, 'I', 'GPE'),
#  (of, 'I', 'GPE'),
#  (the, 'I', 'GPE'),
#  (Czars, 'I', 'GPE'),
#  (and, 'O', ''),
#  (cleared, 'O', ''),
#  (the, 'O', ''),
#  (road, 'O', ''),
#  (to, 'O', ''),
#  (mastery, 'O', ''),
#  (for, 'O', ''),
#  (Mussolini, 'B', 'PERSON'),
#  (in, 'O', ''),
#  (the, 'O', ''),
#  (Rome, 'B', 'GPE'),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (Caesars, 'O', ''),
#  (also, 'O', ''),
#  (paved, 'O', ''),
#  (the, 'O', ''),
#  (way, 'O', ''),
#  (for, 'O', ''),
#  (Hitler, 'B', 'PERSON'),
#  ('s, 'O', ''),
#  (domination, 'O', ''),
#  (in, 'O', ''),
#  (the, 'O', ''),
#  (former, 'O', ''),
#  (mighty, 'O', ''),
#  (Germany, 'B', 'GPE'),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (Hohenzollerns, 'B', 'PERSON'),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (Like, 'O', ''),
#  (Lenin, 'B', 'PERSON'),
#  (and, 'O', ''),
#  (Mussolini, 'B', 'PERSON'),
#  (,, 'O', ''),
#  (Hitler, 'B', 'PERSON'),
#  (came, 'O', ''),
#  (out, 'O', ''),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (blood, 'O', ''),
#  (and, 'O', ''),
#  (chaos, 'O', ''),
#  (of, 'O', ''),
#  (1914, 'B', 'DATE'),
#  (-, 'I', 'DATE'),
#  (18, 'I', 'DATE'),
#  (,, 'O', ''),
#  (but, 'O', ''),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (three, 'B', 'CARDINAL'),
#  (he, 'O', ''),
#  (was, 'O', ''),
#  (the, 'O', ''),
#  (strangest, 'O', ''),
#  (phenomenon, 'O', ''),
#  (., 'O', ''),
#  (Lenin, 'B', 'PERSON'),
#  (,, 'O', ''),
#  (while, 'O', ''),
#  (not, 'O', ''),
#  (know, 'O', ''),
#  (to, 'O', ''),
#  (the, 'O', ''),
#  (general, 'O', ''),
#  (public, 'O', ''),
#  (,, 'O', ''),
#  (had, 'O', ''),
#  (for, 'O', ''),
#  (many, 'O', ''),
#  (years, 'O', ''),
#  (before, 'O', ''),
#  (the, 'B', 'EVENT'),
#  (Russian, 'I', 'EVENT'),
#  (Revolution, 'I', 'EVENT'),
#  (occupied, 'O', ''),
#  (a, 'O', ''),
#  (prominent, 'O', ''),
#  (place, 'O', ''),
#  (as, 'O', ''),
#  (leader, 'O', ''),
#  (and, 'O', ''),
#  (theoretician, 'O', ''),
#  (,, 'O', ''),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (Bolshevist, 'O', ''),
#  (party, 'O', ''),
#  (., 'O', ''),
#  (Mussolini, 'B', 'PERSON'),
#  (was, 'O', ''),
#  (a, 'O', ''),
#  (widely, 'O', ''),
#  (known, 'O', ''),
#  (Socialist, 'B', 'NORP'),
#  (editor, 'O', ''),
#  (,, 'O', ''),
#  (orator, 'O', ''),
#  (and, 'O', ''),
#  (politician, 'O', ''),
#  (before, 'O', ''),
#  (making, 'O', ''),
#  (his, 'O', ''),
#  (bid, 'O', ''),
#  (for, 'O', ''),
#  (power, 'O', ''),
#  (., 'O', ''),
#  (Hitler, 'B', 'PERSON'),
#  (was, 'O', ''),
#  (nothing, 'O', ''),
#  (,, 'O', ''),
#  (and, 'O', ''),
#  (from, 'O', ''),
#  (nothing, 'O', ''),
#  (he, 'O', ''),
#  (became, 'O', ''),
#  (everything, 'O', ''),
#  (to, 'O', ''),
#  (most, 'O', ''),
#  (Germans, 'B', 'NORP'),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (Lenin, 'O', ''),
#  (dreamed, 'O', ''),
#  (of, 'O', ''),
#  (world, 'B', 'EVENT'),
#  (revolution, 'I', 'EVENT'),
#  (., 'O', ''),
#  (Mussolini, 'B', 'PERSON'),
#  (thundered, 'O', ''),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (coming, 'O', ''),
#  (world, 'O', ''),
#  (victory, 'O', ''),
#  (of, 'O', ''),
#  (fascism, 'O', ''),
#  (., 'O', ''),
#  (Hitler, 'B', 'PERSON'),
#  (actually, 'O', ''),
#  (challenged, 'O', ''),
#  (the, 'O', ''),
#  (earth, 'O', ''),
#  (to, 'O', ''),
#  (combat, 'O', ''),
#  (by, 'O', ''),
#  (unleashing, 'O', ''),
#  (another, 'O', ''),
#  (war, 'O', ''),
#  (of, 'O', ''),
#  (nations, 'O', ''),
#  (., 'O', ''),
#  (Emerging, 'O', ''),
#  (from, 'O', ''),
#  (the, 'O', ''),
#  (field, 'O', ''),
#  (in, 'O', ''),
#  (1918, 'B', 'DATE'),
#  (as, 'O', ''),
#  (an, 'O', ''),
#  (obscure, 'O', ''),
#  (lance, 'O', ''),
#  (corporal, 'O', ''),
#  (,, 'O', ''),
#  (he, 'O', ''),
#  (led, 'O', ''),
#  (Germany, 'B', 'GPE'),
#  (twenty, 'O', ''),
#  (-, 'O', ''),
#  (one, 'O', ''),
#  (years, 'O', ''),
#  (later, 'O', ''),
#  (as, 'O', ''),
#  (supreme, 'B', 'ORG'),
#  (Fuehrer, 'I', 'ORG'),
#  (and, 'O', ''),
#  (War, 'O', ''),
#  (Lord, 'O', ''),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (Subdued, 'O', ''),
#  (Many, 'O', ''),
#  (Nations, 'O', ''),
#  (
#
#  , 'O', ''),
#  (Before, 'O', ''),
#  (the, 'O', ''),
#  (climax, 'O', ''),
#  (of, 'O', ''),
#  (a, 'O', ''),
#  (career, 'O', ''),
#  (unparalleled, 'O', ''),
#  (in, 'O', ''),
#  (history, 'O', ''),
#  (,, 'O', ''),
#  (he, 'O', ''),
#  (had, 'O', ''),
#  (subdued, 'O', ''),
#  (nine, 'B', 'CARDINAL'),
#  (nations, 'O', ''),
#  (,, 'O', ''),
#  (defied, 'O', ''),
#  (successfully, 'O', ''),
#  (and, 'O', ''),
#  (humiliated, 'O', ''),
#  (the, 'O', ''),
#  (greatest, 'O', ''),
#  (powers, 'O', ''),
#  (of, 'O', ''),
#  (Europe, 'B', 'LOC'),
#  (,, 'O', ''),
#  (and, 'O', ''),
#  (created, 'O', ''),
#  (a, 'O', ''),
#  (social, 'O', ''),
#  (and, 'O', ''),
#  (economic, 'O', ''),
#  (system, 'O', ''),
#  (founded, 'O', ''),
#  (upon, 'O', ''),
#  (the, 'O', ''),
#  (complete, 'O', ''),
#  (subjection, 'O', ''),
#  (of, 'O', ''),
#  (scores, 'O', ''),
#  (of, 'O', ''),
#  (millions, 'B', 'CARDINAL'),
#  (to, 'O', ''),
#  (his, 'O', ''),
#  (will, 'O', ''),
#  (in, 'O', ''),
#  (all, 'O', ''),
#  (basic, 'O', ''),
#  (features, 'O', ''),
#  (of, 'O', ''),
#  (social, 'O', ''),
#  (,, 'O', ''),
#  (political, 'O', ''),
#  (,, 'O', ''),
#  (economic, 'O', ''),
#  (and, 'O', ''),
#  (cultural, 'O', ''),
#  (life, 'O', ''),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (Sixty, 'O', ''),
#  (-, 'O', ''),
#  (five, 'O', ''),
#  (million, 'O', ''),
#  (Germans, 'B', 'NORP'),
#  (yielded, 'O', ''),
#  (to, 'O', ''),
#  (the, 'O', ''),
#  (blandishments, 'O', ''),
#  (and, 'O', ''),
#  (magnetism, 'O', ''),
#  (of, 'O', ''),
#  (this, 'O', ''),
#  (slender, 'O', ''),
#  (man, 'O', ''),
#  (of, 'O', ''),
#  (medium, 'O', ''),
#  (height, 'O', ''),
#  (,, 'O', ''),
#  (with, 'O', ''),
#  (little, 'O', ''),
#  (black, 'O', ''),
#  (mustache, 'O', ''),
#  (and, 'O', ''),
#  (shock, 'O', ''),
#  (of, 'O', ''),
#  (dark, 'O', ''),
#  (hair, 'O', ''),
#  (,, 'O', ''),
#  (whose, 'O', ''),
#  (fervor, 'O', ''),
#  (and, 'O', ''),
#  (demagogy, 'O', ''),
#  (swept, 'O', ''),
#  (everything, 'O', ''),
#  (before, 'O', ''),
#  (him, 'O', ''),
#  (with, 'O', ''),
#  (outstretched, 'O', ''),
#  (arms, 'O', ''),
#  (as, 'O', ''),
#  (the, 'O', ''),
#  (savior, 'O', ''),
#  (and, 'O', ''),
#  (regenerator, 'O', ''),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (Fatherland, 'B', 'GPE'),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (Austria, 'B', 'GPE'),
#  (,, 'O', ''),
#  (with, 'O', ''),
#  (7,000,000, 'B', 'CARDINAL'),
#  (inhabitants, 'O', ''),
#  (,, 'O', ''),
#  (succumbed, 'O', ''),
#  (helplessly, 'O', ''),
#  (to, 'O', ''),
#  (his, 'O', ''),
#  (invasion, 'O', ''),
#  (., 'O', ''),
#  (More, 'B', 'CARDINAL'),
#  (than, 'I', 'CARDINAL'),
#  (2,000,000, 'I', 'CARDINAL'),
#  (Germans, 'B', 'NORP'),
#  (in, 'O', ''),
#  (the, 'O', ''),
#  (Sudeten, 'B', 'PERSON'),
#  (country, 'O', ''),
#  (were, 'O', ''),
#  (added, 'O', ''),
#  (to, 'O', ''),
#  (his, 'O', ''),
#  (domain, 'O', ''),
#  (when, 'O', ''),
#  (he, 'O', ''),
#  (threatened, 'O', ''),
#  (to, 'O', ''),
#  (invade, 'O', ''),
#  (Czechoslovakia, 'B', 'GPE'),
#  (,, 'O', ''),
#  (and, 'O', ''),
#  (10,000,000, 'B', 'CARDINAL'),
#  (Czechs, 'B', 'NORP'),
#  (and, 'O', ''),
#  (Slovaks, 'B', 'NORP'),
#  (were, 'O', ''),
#  (tied, 'O', ''),
#  (to, 'O', ''),
#  (his, 'O', ''),
#  (chariot, 'O', ''),
#  (wheel, 'O', ''),
#  (,, 'O', ''),
#  (their, 'O', ''),
#  (nation, 'O', ''),
#  (stripped, 'O', ''),
#  (of, 'O', ''),
#  (its, 'O', ''),
#  (defenses, 'O', ''),
#  (,, 'O', ''),
#  (their, 'O', ''),
#  (State, 'B', 'ORG'),
#  (destroyed, 'O', ''),
#  (,, 'O', ''),
#  (while, 'O', ''),
#  (all, 'O', ''),
#  (of, 'O', ''),
#  (Central, 'B', 'LOC'),
#  (Europe, 'I', 'LOC'),
#  (trembled, 'O', ''),
#  (before, 'O', ''),
#  (what, 'O', ''),
#  (appeared, 'O', ''),
#  (to, 'O', ''),
#  (be, 'O', ''),
#  (the, 'O', ''),
#  (irresistible, 'O', ''),
#  (advance, 'O', ''),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (goose-, 'O', ''),
#  (stepping, 'O', ''),
#  (Nazi, 'B', 'NORP'),
#  (hordes, 'O', ''),
#  (of, 'O', ''),
#  (his, 'O', ''),
#  (adopted, 'O', ''),
#  (country, 'O', ''),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (For, 'O', ''),
#  (more, 'B', 'DATE'),
#  (than, 'I', 'DATE'),
#  (six, 'I', 'DATE'),
#  (years, 'I', 'DATE'),
#  (after, 'O', ''),
#  (his, 'O', ''),
#  (advent, 'O', ''),
#  (to, 'O', ''),
#  (power, 'O', ''),
#  (in, 'O', ''),
#  (January, 'B', 'DATE'),
#  (,, 'I', 'DATE'),
#  (1933, 'I', 'DATE'),
#  (,, 'O', ''),
#  (there, 'O', ''),
#  (seemed, 'O', ''),
#  (to, 'O', ''),
#  (be, 'O', ''),
#  (no, 'O', ''),
#  (one, 'O', ''),
#  (who, 'O', ''),
#  (would, 'O', ''),
#  (dare, 'O', ''),
#  (to, 'O', ''),
#  (challenge, 'O', ''),
#  (Hitler, 'B', 'PERSON'),
#  ('s, 'O', ''),
#  (progress, 'O', ''),
#  (from, 'O', ''),
#  (victory, 'O', ''),
#  (to, 'O', ''),
#  (victory, 'O', ''),
#  (until, 'O', ''),
#  (he, 'O', ''),
#  (met, 'O', ''),
#  (resistance, 'O', ''),
#  (from, 'O', ''),
#  (Poland, 'B', 'GPE'),
#  (,, 'O', ''),
#  (backed, 'O', ''),
#  (by, 'O', ''),
#  (the, 'O', ''),
#  (Anglo, 'B', 'NORP'),
#  (-, 'O', ''),
#  (French, 'O', ''),
#  (alliance, 'O', ''),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (Shortly, 'O', ''),
#  (after, 'O', ''),
#  (his, 'O', ''),
#  (dismemberment, 'O', ''),
#  (and, 'O', ''),
#  (subjugation, 'O', ''),
#  (of, 'O', ''),
#  (Czechoslovakia, 'B', 'PERSON'),
#  (Hitler, 'I', 'PERSON'),
#  (was, 'O', ''),
#  (reported, 'O', ''),
#  (to, 'O', ''),
#  (have, 'O', ''),
#  (said, 'O', ''),
#  (,, 'O', ''),
#  (", 'O', ''),
#  (My, 'O', ''),
#  (time, 'O', ''),
#  (is, 'O', ''),
#  (short, 'O', ''),
#  (., 'O', ''),
#  (", 'O', ''),
#  (His, 'O', ''),
#  (blow, 'O', ''),
#  (against, 'O', ''),
#  (Poland, 'B', 'GPE'),
#  (and, 'O', ''),
#  (challenge, 'O', ''),
#  (to, 'O', ''),
#  (France, 'B', 'GPE'),
#  (and, 'O', ''),
#  (England, 'B', 'GPE'),
#  (less, 'B', 'DATE'),
#  (than, 'I', 'DATE'),
#  (a, 'I', 'DATE'),
#  (year, 'I', 'DATE'),
#  (later, 'I', 'DATE'),
#  (were, 'O', ''),
#  (taken, 'O', ''),
#  (as, 'O', ''),
#  (indications, 'O', ''),
#  (that, 'O', ''),
#  (he, 'O', ''),
#  (had, 'O', ''),
#  (determined, 'O', ''),
#  (deliberately, 'O', ''),
#  (to, 'O', ''),
#  (stake, 'O', ''),
#  (all, 'O', ''),
#  (he, 'O', ''),
#  (had, 'O', ''),
#  (achieved, 'O', ''),
#  (and, 'O', ''),
#  (all, 'O', ''),
#  (that, 'O', ''),
#  (he, 'O', ''),
#  (still, 'O', ''),
#  (yearned, 'O', ''),
#  (for, 'O', ''),
#  (--, 'O', ''),
#  (domination, 'O', ''),
#  (of, 'O', ''),
#  (Europe, 'B', 'LOC'),
#  (--, 'O', ''),
#  (upon, 'O', ''),
#  (one, 'B', 'CARDINAL'),
#  (card, 'O', ''),
#  (,, 'O', ''),
#  (war, 'O', ''),
#  (,, 'O', ''),
#  (sensing, 'O', ''),
#  (,, 'O', ''),
#  (perhaps, 'O', ''),
#  (,, 'O', ''),
#  (that, 'O', ''),
#  (time, 'O', ''),
#  (was, 'O', ''),
#  (against, 'O', ''),
#  (him, 'O', ''),
#  (,, 'O', ''),
#  (that, 'O', ''),
#  (he, 'O', ''),
#  (had, 'O', ''),
#  (unleashed, 'O', ''),
#  (forces, 'O', ''),
#  (of, 'O', ''),
#  (hatred, 'O', ''),
#  (and, 'O', ''),
#  (opposition, 'O', ''),
#  (throughout, 'O', ''),
#  (the, 'O', ''),
#  (world, 'O', ''),
#  (that, 'O', ''),
#  (might, 'O', ''),
#  (eventually, 'O', ''),
#  (destroy, 'O', ''),
#  (him, 'O', ''),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (Series, 'O', ''),
#  (of, 'O', ''),
#  (Broken, 'O', ''),
#  (Promises, 'O', ''),
#  (
#
#  , 'O', ''),
#  (Those, 'O', ''),
#  (who, 'O', ''),
#  (had, 'O', ''),
#  (hoped, 'O', ''),
#  (that, 'O', ''),
#  (success, 'O', ''),
#  (at, 'O', ''),
#  (home, 'O', ''),
#  (and, 'O', ''),
#  (extension, 'O', ''),
#  (of, 'O', ''),
#  (his, 'O', ''),
#  (power, 'O', ''),
#  (abroad, 'O', ''),
#  (would, 'O', ''),
#  (make, 'O', ''),
#  (him, 'O', ''),
#  (more, 'O', ''),
#  (circumspect, 'O', ''),
#  (and, 'O', ''),
#  (reluctant, 'O', ''),
#  (to, 'O', ''),
#  (pursue, 'O', ''),
#  (the, 'O', ''),
#  (program, 'O', ''),
#  (of, 'O', ''),
#  (conquest, 'O', ''),
#  (he, 'O', ''),
#  (had, 'O', ''),
#  (outlined, 'O', ''),
#  (for, 'O', ''),
#  (himself, 'O', ''),
#  (in, 'O', ''),
#  (", 'B', 'WORK_OF_ART'),
#  (Mein, 'I', 'WORK_OF_ART'),
#  (Kampf, 'I', 'WORK_OF_ART'),
#  (", 'I', 'WORK_OF_ART'),
#  (and, 'O', ''),
#  (in, 'O', ''),
#  (his, 'O', ''),
#  (speeches, 'O', ''),
#  (had, 'O', ''),
#  (abandoned, 'O', ''),
#  (that, 'O', ''),
#  (hope, 'O', ''),
#  (when, 'O', ''),
#  (,, 'O', ''),
#  (in, 'O', ''),
#  (violation, 'O', ''),
#  (of, 'O', ''),
#  (his, 'O', ''),
#  (promise, 'O', ''),
#  (to, 'O', ''),
#  (respect, 'O', ''),
#  (the, 'O', ''),
#  (integrity, 'O', ''),
#  (of, 'O', ''),
#  (Czechoslovakia, 'B', 'GPE'),
#  (after, 'O', ''),
#  (Munich, 'B', 'GPE'),
#  (,, 'O', ''),
#  (he, 'O', ''),
#  (marched, 'O', ''),
#  (on, 'O', ''),
#  (Prague, 'B', 'GPE'),
#  (and, 'O', ''),
#  (reduced, 'O', ''),
#  (that, 'O', ''),
#  (nation, 'O', ''),
#  (to, 'O', ''),
#  (a, 'O', ''),
#  (German, 'B', 'NORP'),
#  (protectorate, 'O', ''),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (It, 'O', ''),
#  (was, 'O', ''),
#  (not, 'O', ''),
#  (the, 'O', ''),
#  (first, 'B', 'ORDINAL'),
#  (promise, 'O', ''),
#  (he, 'O', ''),
#  (had, 'O', ''),
#  (broken, 'O', ''),
#  (., 'O', ''),
#  (His, 'O', ''),
#  (whole, 'O', ''),
#  (course, 'O', ''),
#  (at, 'O', ''),
#  (home, 'O', ''),
#  (and, 'O', ''),
#  (abroad, 'O', ''),
#  (had, 'O', ''),
#  (been, 'O', ''),
#  (marked, 'O', ''),
#  (by, 'O', ''),
#  (broken, 'O', ''),
#  (promises, 'O', ''),
#  (and, 'O', ''),
#  (he, 'O', ''),
#  (did, 'O', ''),
#  (not, 'O', ''),
#  (hesitate, 'O', ''),
#  (to, 'O', ''),
#  (massacre, 'O', ''),
#  (many, 'O', ''),
#  (of, 'O', ''),
#  (his, 'O', ''),
#  (own, 'O', ''),
#  (closest, 'O', ''),
#  (adherents, 'O', ''),
#  (,, 'O', ''),
#  (as, 'O', ''),
#  (he, 'O', ''),
#  (did, 'O', ''),
#  (in, 'O', ''),
#  (the, 'O', ''),
#  (purge, 'O', ''),
#  (of, 'O', ''),
#  (June, 'B', 'DATE'),
#  (,, 'I', 'DATE'),
#  (1934, 'I', 'DATE'),
#  (,, 'O', ''),
#  (when, 'O', ''),
#  (he, 'O', ''),
#  (personally, 'O', ''),
#  (directed, 'O', ''),
#  (the, 'O', ''),
#  (killing, 'O', ''),
#  (of, 'O', ''),
#  (Capt, 'O', ''),
#  (., 'O', ''),
#  (Ernst, 'B', 'PERSON'),
#  (Roehm, 'I', 'PERSON'),
#  (and, 'O', ''),
#  (a, 'O', ''),
#  (group, 'O', ''),
#  (of, 'O', ''),
#  (leading, 'O', ''),
#  (Nazis, 'B', 'NORP'),
#  (who, 'O', ''),
#  (had, 'O', ''),
#  (ventured, 'O', ''),
#  (to, 'O', ''),
#  (interfere, 'O', ''),
#  (in, 'O', ''),
#  (his, 'O', ''),
#  (plans, 'O', ''),
#  (for, 'O', ''),
#  (a, 'O', ''),
#  (closer, 'O', ''),
#  (association, 'O', ''),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (Reichswehr, 'O', ''),
#  (with, 'O', ''),
#  (the, 'O', ''),
#  (regime, 'O', ''),
#  (and, 'O', ''),
#  (insisted, 'O', ''),
#  (upon, 'O', ''),
#  (fulfillment, 'O', ''),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (original, 'O', ''),
#  (Nazi, 'B', 'NORP'),
#  (party, 'O', ''),
#  (promises, 'O', ''),
#  (in, 'O', ''),
#  (the, 'O', ''),
#  (economic, 'O', ''),
#  (field, 'O', ''),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (The, 'O', ''),
#  (world, 'O', ''),
#  (-, 'O', ''),
#  (wide, 'O', ''),
#  (condemnation, 'O', ''),
#  (of, 'O', ''),
#  (his, 'O', ''),
#  (methods, 'O', ''),
#  (was, 'O', ''),
#  (fed, 'O', ''),
#  (by, 'O', ''),
#  (the, 'O', ''),
#  (system, 'O', ''),
#  (of, 'O', ''),
#  (terrorism, 'O', ''),
#  (he, 'O', ''),
#  (had, 'O', ''),
#  (established, 'O', ''),
#  (at, 'O', ''),
#  (home, 'O', ''),
#  (and, 'O', ''),
#  (in, 'O', ''),
#  (the, 'O', ''),
#  (countries, 'O', ''),
#  (he, 'O', ''),
#  (had, 'O', ''),
#  (conquered, 'O', ''),
#  (,, 'O', ''),
#  (the, 'O', ''),
#  (jailing, 'O', ''),
#  (of, 'O', ''),
#  (scores, 'O', ''),
#  (of, 'O', ''),
#  (thousands, 'B', 'CARDINAL'),
#  (in, 'O', ''),
#  (prisons, 'O', ''),
#  (and, 'O', ''),
#  (concentration, 'O', ''),
#  (camps, 'O', ''),
#  (,, 'O', ''),
#  (the, 'O', ''),
#  (secret, 'O', ''),
#  (murder, 'O', ''),
#  (of, 'O', ''),
#  (opponents, 'O', ''),
#  (and, 'O', ''),
#  (those, 'O', ''),
#  (suspected, 'O', ''),
#  (of, 'O', ''),
#  (opposition, 'O', ''),
#  (,, 'O', ''),
#  (the, 'O', ''),
#  (ruthless, 'O', ''),
#  (destruction, 'O', ''),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (Jews, 'B', 'NORP'),
#  (and, 'O', ''),
#  (the, 'O', ''),
#  (persecution, 'O', ''),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (Catholic, 'B', 'NORP'),
#  (and, 'O', ''),
#  (Protestant, 'O', ''),
#  (Churches, 'O', ''),
#  (in, 'O', ''),
#  (his, 'O', ''),
#  (drive, 'O', ''),
#  (for, 'O', ''),
#  (nazification, 'O', ''),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (nation, 'O', ''),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (Churches, 'O', ''),
#  (Persecuted, 'O', ''),
#  (Under, 'O', ''),
#  (Nazis, 'B', 'NORP'),
#  (', 'O', ''),
#  (Paganism, 'O', ''),
#  (;, 'O', ''),
#  (Pastor, 'O', ''),
#  (Niemoeller, 'O', ''),
#  (Pre, 'O', ''),
#  (-, 'O', ''),
#  (Eminent, 'O', ''),
#  (in, 'O', ''),
#  (
#
#  , 'O', ''),
#  (Opposition, 'O', ''),
#  (
#
#  , 'O', ''),
#  (It, 'O', ''),
#  (was, 'O', ''),
#  (not, 'O', ''),
#  (long, 'O', ''),
#  (after, 'O', ''),
#  (his, 'O', ''),
#  (coming, 'O', ''),
#  (to, 'O', ''),
#  (power, 'O', ''),
#  (that, 'O', ''),
#  (the, 'O', ''),
#  (churches, 'O', ''),
#  (found, 'O', ''),
#  (themselves, 'O', ''),
#  (at, 'O', ''),
#  (war, 'O', ''),
#  (with, 'O', ''),
#  (Hitler, 'B', 'PERSON'),
#  (and, 'O', ''),
#  (his, 'O', ''),
#  (regime, 'O', ''),
#  (when, 'O', ''),
#  (they, 'O', ''),
#  (discovered, 'O', ''),
#  (that, 'O', ''),
#  (what, 'O', ''),
#  (he, 'O', ''),
#  (aimed, 'O', ''),
#  (at, 'O', ''),
#  (was, 'O', ''),
#  (no, 'O', ''),
#  (less, 'O', ''),
#  (than, 'O', ''),
#  (the, 'O', ''),
#  (substitution, 'O', ''),
#  (of, 'O', ''),
#  (a, 'O', ''),
#  (pagan, 'O', ''),
#  (
#
#  , 'O', ''),
#  (German, 'O', ''),
#  (god, 'O', ''),
#  (for, 'O', ''),
#  (Christ, 'O', ''),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (Some, 'O', ''),
#  (brave, 'O', ''),
#  (representatives, 'O', ''),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (churches, 'O', ''),
#  (defied, 'O', ''),
#  (Hitler, 'B', 'PERSON'),
#  (when, 'O', ''),
#  (all, 'O', ''),
#  (others, 'O', ''),
#  (had, 'O', ''),
#  (been, 'O', ''),
#  (broken, 'O', ''),
#  (., 'O', ''),
#  (Of, 'O', ''),
#  (these, 'B', 'ORG'),
#  (Pastor, 'I', 'ORG'),
#  (Niemoeller, 'I', 'ORG'),
#  (was, 'O', ''),
#  (pre, 'O', ''),
#  (-, 'O', ''),
#  (eminent, 'O', ''),
#  (., 'O', ''),
#  (In, 'O', ''),
#  (his, 'O', ''),
#  (prison, 'O', ''),
#  (cell, 'O', ''),
#  (Niemoeller, 'B', 'PERSON'),
#  (became, 'O', ''),
#  (the, 'O', ''),
#  (symbol, 'O', ''),
#  (of, 'O', ''),
#  (Christianity, 'B', 'ORG'),
#  (struggling, 'O', ''),
#  (to, 'O', ''),
#  (maintain, 'O', ''),
#  (its, 'O', ''),
#  (truth, 'O', ''),
#  (and, 'O', ''),
#  (identity, 'O', ''),
#  (against, 'O', ''),
#  (the, 'O', ''),
#  (Nazi, 'B', 'NORP'),
#  (State, 'B', 'ORG'),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (Mass, 'O', ''),
#  (Unrest, 'O', ''),
#  (His, 'O', ''),
#  (Springboard, 'O', ''),
#  (
#
#  , 'O', ''),
#  (The, 'O', ''),
#  (social, 'O', ''),
#  (,, 'O', ''),
#  (political, 'O', ''),
#  (and, 'O', ''),
#  (economic, 'O', ''),
#  (conditions, 'O', ''),
#  (,, 'O', ''),
#  (as, 'O', ''),
#  (they, 'O', ''),
#  (developed, 'O', ''),
#  (in, 'O', ''),
#  (post, 'O', ''),
#  (-, 'O', ''),
#  (war, 'O', ''),
#  (Germany, 'B', 'GPE'),
#  (,, 'O', ''),
#  (smarting, 'O', ''),
#  (painfully, 'O', ''),
#  (under, 'O', ''),
#  (humiliation, 'O', ''),
#  (and, 'O', ''),
#  (defeat, 'O', ''),
#  (and, 'O', ''),
#  (struggling, 'O', ''),
#  (for, 'O', ''),
#  (nearly, 'B', 'DATE'),
#  (fifteen, 'I', 'DATE'),
#  (years, 'I', 'DATE'),
#  (with, 'O', ''),
#  (internal, 'O', ''),
#  (dissension, 'O', ''),
#  (and, 'O', ''),
#  (mass, 'O', ''),
#  (unemployment, 'O', ''),
#  (,, 'O', ''),
#  (supplied, 'O', ''),
#  (the, 'O', ''),
#  (springboard, 'O', ''),
#  (for, 'O', ''),
#  (Hitler, 'B', 'PERSON'),
#  ('s, 'O', ''),
#  (leap, 'O', ''),
#  (to, 'O', ''),
#  (power, 'O', ''),
#  (in, 'O', ''),
#  (1933, 'B', 'DATE'),
#  (., 'O', ''),
#  (Having, 'O', ''),
#  (become, 'O', ''),
#  (disappointed, 'O', ''),
#  (in, 'O', ''),
#  (all, 'O', ''),
#  (other, 'O', ''),
#  (parties, 'O', ''),
#  (,, 'O', ''),
#  (a, 'O', ''),
#  (sufficient, 'O', ''),
#  (number, 'O', ''),
#  (of, 'O', ''),
#  (Germans, 'B', 'NORP'),
#  (had, 'O', ''),
#  (accepted, 'O', ''),
#  (the, 'O', ''),
#  (Nazis, 'B', 'NORP'),
#  (when, 'O', ''),
#  (the, 'O', ''),
#  (latter, 'O', ''),
#  (,, 'O', ''),
#  (by, 'O', ''),
#  (means, 'O', ''),
#  (of, 'O', ''),
#  (force, 'O', ''),
#  (and, 'O', ''),
#  (propaganda, 'O', ''),
#  (ingeniously, 'O', ''),
#  (directed, 'O', ''),
#  (by, 'O', ''),
#  (Hitler, 'B', 'PERSON'),
#  (,, 'O', ''),
#  (had, 'O', ''),
#  (maneuvered, 'O', ''),
#  (themselves, 'O', ''),
#  (into, 'O', ''),
#  (a, 'O', ''),
#  (position, 'O', ''),
#  (from, 'O', ''),
#  (which, 'O', ''),
#  (they, 'O', ''),
#  (could, 'O', ''),
#  (strike, 'O', ''),
#  (for, 'O', ''),
#  (seizure, 'O', ''),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (Government, 'O', ''),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (But, 'O', ''),
#  (an, 'O', ''),
#  (understanding, 'O', ''),
#  (of, 'O', ''),
#  (Hitler, 'B', 'PERSON'),
#  ('s, 'O', ''),
#  (conduct, 'O', ''),
#  (both, 'O', ''),
#  (before, 'O', ''),
#  (and, 'O', ''),
#  (after, 'O', ''),
#  (his, 'O', ''),
#  (advent, 'O', ''),
#  (to, 'O', ''),
#  (power, 'O', ''),
#  (has, 'O', ''),
#  (been, 'O', ''),
#  (sought, 'O', ''),
#  (by, 'O', ''),
#  (students, 'O', ''),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (man, 'O', ''),
#  (in, 'O', ''),
#  (study, 'O', ''),
#  (of, 'O', ''),
#  (his, 'O', ''),
#  (youth, 'O', ''),
#  (and, 'O', ''),
#  (family, 'O', ''),
#  (history, 'O', ''),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (One, 'O', ''),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (most, 'O', ''),
#  (striking, 'O', ''),
#  (contradictions, 'O', ''),
#  (was, 'O', ''),
#  (the, 'O', ''),
#  (discrepancy, 'O', ''),
#  (between, 'O', ''),
#  (the, 'O', ''),
#  (magnetism, 'O', ''),
#  (he, 'O', ''),
#  (exercised, 'O', ''),
#  (over, 'B', 'CARDINAL'),
#  (millions, 'I', 'CARDINAL'),
#  (and, 'O', ''),
#  (the, 'O', ''),
#  (unprepossessing, 'O', ''),
#  (appearance, 'O', ''),
#  (of, 'O', ''),
#  (this, 'O', ''),
#  (champion, 'O', ''),
#  (of, 'O', ''),
#  (Aryan, 'B', 'NORP'),
#  (race, 'O', ''),
#  (purity, 'O', ''),
#  (., 'O', ''),
#  (Professor, 'O', ''),
#  (Max, 'B', 'PERSON'),
#  (von, 'I', 'PERSON'),
#  (
#
#  , 'I', 'PERSON'),
#  (Gruber, 'I', 'PERSON'),
#  (,, 'O', ''),
#  (noted, 'O', ''),
#  (German, 'B', 'NORP'),
#  (authority, 'O', ''),
#  (on, 'O', ''),
#  (race, 'O', ''),
#  (hygiene, 'O', ''),
#  (,, 'O', ''),
#  (gave, 'O', ''),
#  (the, 'O', ''),
#  (following, 'O', ''),
#  (description, 'O', ''),
#  (of, 'O', ''),
#  (Hitler, 'B', 'PERSON'),
#  (when, 'O', ''),
#  (he, 'O', ''),
#  (met, 'O', ''),
#  (him, 'O', ''),
#  (for, 'O', ''),
#  (the, 'O', ''),
#  (first, 'B', 'ORDINAL'),
#  (time, 'O', ''),
#  (at, 'O', ''),
#  (a, 'O', ''),
#  (political, 'O', ''),
#  (trial, 'O', ''),
#  (in, 'O', ''),
#  (a, 'O', ''),
#  (German, 'B', 'NORP'),
#  (court, 'O', ''),
#  (in, 'O', ''),
#  (1923, 'B', 'DATE'),
#  (:, 'O', ''),
#  (", 'O', ''),
#  (Face, 'O', ''),
#  (and, 'O', ''),
#  (head, 'O', ''),
#  (,, 'O', ''),
#  (bad, 'O', ''),
#  (--, 'O', ''),
#  (mongrel, 'O', ''),
#  (., 'O', ''),
#  (Low, 'O', ''),
#  (,, 'O', ''),
#  (receding, 'O', ''),
#  (forehead, 'O', ''),
#  (,, 'O', ''),
#  (unhandsome, 'O', ''),
#  (nose, 'O', ''),
#  (,, 'O', ''),
#  (broad, 'O', ''),
#  (cheekbones, 'O', ''),
#  (,, 'O', ''),
#  (small, 'O', ''),
#  (eyes, 'O', ''),
#  (,, 'O', ''),
#  (dark, 'O', ''),
#  (hair, 'O', ''),
#  (., 'O', ''),
#  (Expression, 'O', ''),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (face, 'O', ''),
#  (not, 'O', ''),
#  (that, 'O', ''),
#  (of, 'O', ''),
#  (one, 'B', 'CARDINAL'),
#  (commanding, 'O', ''),
#  (full, 'O', ''),
#  (self, 'O', ''),
#  (-, 'O', ''),
#  (control, 'O', ''),
#  (,, 'O', ''),
#  (but, 'O', ''),
#  (of, 'O', ''),
#  (one, 'B', 'CARDINAL'),
#  (instantly, 'O', ''),
#  (excited, 'O', ''),
#  (., 'O', ''),
#  (At, 'O', ''),
#  (the, 'O', ''),
#  (end, 'O', ''),
#  (--, 'O', ''),
#  (the, 'O', ''),
#  (expression, 'O', ''),
#  (of, 'O', ''),
#  (happy, 'O', ''),
#  (complacency, 'O', ''),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (Many, 'O', ''),
#  (who, 'O', ''),
#  (watched, 'O', ''),
#  (Hitler, 'B', 'PERSON'),
#  (from, 'O', ''),
#  (the, 'O', ''),
#  (time, 'O', ''),
#  (when, 'O', ''),
#  (he, 'O', ''),
#  (first, 'B', 'ORDINAL'),
#  (made, 'O', ''),
#  (his, 'O', ''),
#  (appearance, 'O', ''),
#  (on, 'O', ''),
#  (the, 'O', ''),
#  (political, 'O', ''),
#  (scene, 'O', ''),
#  (noticed, 'O', ''),
#  (his, 'O', ''),
#  (megalomania, 'O', ''),
#  (,, 'O', ''),
#  (his, 'O', ''),
#  (gambler, 'O', ''),
#  ('s, 'O', ''),
#  (readiness, 'O', ''),
#  (to, 'O', ''),
#  (take, 'O', ''),
#  (risks, 'O', ''),
#  (,, 'O', ''),
#  (his, 'O', ''),
#  (habit, 'O', ''),
#  (of, 'O', ''),
#  (wild, 'O', ''),
#  (exaggeration, 'O', ''),
#  (and, 'O', ''),
#  (inability, 'O', ''),
#  (to, 'O', ''),
#  (grasp, 'O', ''),
#  (the, 'O', ''),
#  (full, 'O', ''),
#  (implications, 'O', ''),
#  (of, 'O', ''),
#  (things, 'O', ''),
#  (he, 'O', ''),
#  (said, 'O', ''),
#  (and, 'O', ''),
#  (did, 'O', ''),
#  (., 'O', ''),
#  (It, 'O', ''),
#  (was, 'O', ''),
#  (this, 'O', ''),
#  (failure, 'O', ''),
#  (to, 'O', ''),
#  (measure, 'O', ''),
#  (the, 'O', ''),
#  (significance, 'O', ''),
#  (of, 'O', ''),
#  (his, 'O', ''),
#  (words, 'O', ''),
#  (and, 'O', ''),
#  (deeds, 'O', ''),
#  (that, 'O', ''),
#  (was, 'O', ''),
#  (considered, 'O', ''),
#  (responsible, 'O', ''),
#  (for, 'O', ''),
#  (the, 'O', ''),
#  (coolness, 'O', ''),
#  (he, 'O', ''),
#  (displayed, 'O', ''),
#  (at, 'O', ''),
#  (critical, 'O', ''),
#  (moments, 'O', ''),
#  (after, 'O', ''),
#  (violent, 'O', ''),
#  (outbursts, 'O', ''),
#  (of, 'O', ''),
#  (thought, 'O', ''),
#  (and, 'O', ''),
#  (temper, 'O', ''),
#  (,, 'O', ''),
#  (although, 'O', ''),
#  (on, 'O', ''),
#  (occasions, 'O', ''),
#  (he, 'O', ''),
#  (was, 'O', ''),
#  (reported, 'O', ''),
#  (to, 'O', ''),
#  (fall, 'O', ''),
#  (into, 'O', ''),
#  (tears, 'O', ''),
#  (and, 'O', ''),
#  (hysterics, 'O', ''),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (Propaganda, 'O', ''),
#  (a, 'O', ''),
#  (Basic, 'O', ''),
#  (Weapon, 'O', ''),
#  (
#
#  , 'O', ''),
#  (At, 'O', ''),
#  (the, 'O', ''),
#  (same, 'O', ''),
#  (time, 'O', ''),
#  (,, 'O', ''),
#  (however, 'O', ''),
#  (,, 'O', ''),
#  (he, 'O', ''),
#  (possessed, 'O', ''),
#  (an, 'O', ''),
#  (uncanny, 'O', ''),
#  (shrewdness, 'O', ''),
#  (in, 'O', ''),
#  (his, 'O', ''),
#  (estimate, 'O', ''),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (conduct, 'O', ''),
#  (and, 'O', ''),
#  (psychology, 'O', ''),
#  (of, 'O', ''),
#  (masses, 'O', ''),
#  (and, 'O', ''),
#  (individuals, 'O', ''),
#  (,, 'O', ''),
#  (and, 'O', ''),
#  (developed, 'O', ''),
#  (to, 'O', ''),
#  (a, 'O', ''),
#  (fine, 'O', ''),
#  (degree, 'O', ''),
#  (the, 'O', ''),
#  (art, 'O', ''),
#  (of, 'O', ''),
#  (swaying, 'O', ''),
#  (their, 'O', ''),
#  (emotions, 'O', ''),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (The, 'O', ''),
#  (success, 'O', ''),
#  (he, 'O', ''),
#  (achieved, 'O', ''),
#  (in, 'O', ''),
#  (this, 'O', ''),
#  (field, 'O', ''),
#  (enhanced, 'O', ''),
#  (his, 'O', ''),
#  (contempt, 'O', ''),
#  (for, 'O', ''),
#  (the, 'O', ''),
#  (people, 'O', ''),
#  (,, 'O', ''),
#  (whom, 'O', ''),
#  (he, 'O', ''),
#  (called, 'O', ''),
#  (a, 'O', ''),
#  (", 'O', ''),
#  (flock, 'O', ''),
#  (of, 'O', ''),
#  (sheep, 'O', ''),
#  (and, 'O', ''),
#  (blockheads, 'O', ''),
#  (,, 'O', ''),
#  (", 'O', ''),
#  (a, 'O', ''),
#  (", 'O', ''),
#  (mixture, 'O', ''),
#  (of, 'O', ''),
#  (stupidity, 'O', ''),
#  (and, 'O', ''),
#  (cowardice, 'O', ''),
#  (., 'O', ''),
#  (", 'O', ''),
#  (He, 'O', ''),
#  (was, 'O', ''),
#  (convinced, 'O', ''),
#  (that, 'O', ''),
#  (well, 'O', ''),
#  (-, 'O', ''),
#  (directed, 'O', ''),
#  (propaganda, 'O', ''),
#  (by, 'O', ''),
#  (a, 'O', ''),
#  (determined, 'O', ''),
#  (minority, 'O', ''),
#  (backed, 'O', ''),
#  (by, 'O', ''),
#  (force, 'O', ''),
#  (at, 'O', ''),
#  (the, 'O', ''),
#  (strategic, 'O', ''),
#  (moment, 'O', ''),
#  (,, 'O', ''),
#  (constituted, 'O', ''),
#  (a, 'O', ''),
#  (sure, 'O', ''),
#  (road, 'O', ''),
#  (to, 'O', ''),
#  (victory, 'O', ''),
#  (., 'O', ''),
#  (", 'O', ''),
#  (By, 'O', ''),
#  (shrewd, 'O', ''),
#  (and, 'O', ''),
#  (constant, 'O', ''),
#  (application, 'O', ''),
#  (of, 'O', ''),
#  (propaganda, 'O', ''),
#  (,, 'O', ''),
#  (heaven, 'O', ''),
#  (can, 'O', ''),
#  (be, 'O', ''),
#  (presented, 'O', ''),
#  (to, 'O', ''),
#  (the, 'O', ''),
#  (people, 'O', ''),
#  (as, 'O', ''),
#  (hell, 'O', ''),
#  (and, 'O', ''),
#  (,, 'O', ''),
#  (vice, 'O', ''),
#  (versa, 'O', ''),
#  (,, 'O', ''),
#  (the, 'O', ''),
#  (wretchedest, 'O', ''),
#  (existence, 'O', ''),
#  (as, 'O', ''),
#  (a, 'O', ''),
#  (paradise, 'O', ''),
#  (,, 'O', ''),
#  (", 'O', ''),
#  (he, 'O', ''),
#  (wrote, 'O', ''),
#  (in, 'O', ''),
#  (", 'O', ''),
#  (Mein, 'B', 'WORK_OF_ART'),
#  (Kampf, 'I', 'WORK_OF_ART'),
#  (., 'O', ''),
#  (", 'O', ''),
#  (
#
#  , 'O', ''),
#  (This, 'O', ''),
#  (contempt, 'O', ''),
#  (for, 'O', ''),
#  (the, 'O', ''),
#  (people, 'O', ''),
#  (and, 'O', ''),
#  (his, 'O', ''),
#  (unbounded, 'O', ''),
#  (capacity, 'O', ''),
#  (for, 'O', ''),
#  (hatred, 'O', ''),
#  (,, 'O', ''),
#  (which, 'O', ''),
#  (found, 'O', ''),
#  (expression, 'O', ''),
#  (in, 'O', ''),
#  (his, 'O', ''),
#  (merciless, 'O', ''),
#  (treatment, 'O', ''),
#  (of, 'O', ''),
#  (opponents, 'O', ''),
#  (and, 'O', ''),
#  (persecution, 'O', ''),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (Jews, 'B', 'NORP'),
#  (,, 'O', ''),
#  (according, 'O', ''),
#  (to, 'O', ''),
#  (psychologists, 'O', ''),
#  (who, 'O', ''),
#  (have, 'O', ''),
#  (studied, 'O', ''),
#  (the, 'O', ''),
#  (man, 'O', ''),
#  ('s, 'O', ''),
#  (career, 'O', ''),
#  (closely, 'O', ''),
#  (,, 'O', ''),
#  (emanated, 'O', ''),
#  (in, 'O', ''),
#  (Hitler, 'B', 'PERSON'),
#  (from, 'O', ''),
#  (the, 'O', ''),
#  (poverty, 'O', ''),
#  (,, 'O', ''),
#  (wretchedness, 'O', ''),
#  (and, 'O', ''),
#  (frustrations, 'O', ''),
#  (of, 'O', ''),
#  (his, 'O', ''),
#  (youth, 'O', ''),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (Hitler, 'B', 'PERSON'),
#  (was, 'O', ''),
#  (born, 'O', ''),
#  (in, 'O', ''),
#  (an, 'O', ''),
#  (inn, 'O', ''),
#  (at, 'O', ''),
#  (Braynau, 'B', 'GPE'),
#  (,, 'O', ''),
#  (Austria, 'B', 'GPE'),
#  (,, 'O', ''),
#  (close, 'O', ''),
#  (to, 'O', ''),
#  (the, 'O', ''),
#  (German, 'B', 'NORP'),
#  (frontier, 'O', ''),
#  (,, 'O', ''),
#  (April, 'B', 'DATE'),
#  (20, 'I', 'DATE'),
#  (,, 'I', 'DATE'),
#  (1889, 'I', 'DATE'),
#  (., 'O', ''),
#  (His, 'O', ''),
#  (father, 'O', ''),
#  (was, 'O', ''),
#  (Alois, 'B', 'PERSON'),
#  (Schickelgruber, 'I', 'PERSON'),
#  (,, 'O', ''),
#  (the, 'O', ''),
#  (illegitimate, 'O', ''),
#  (son, 'O', ''),
#  (of, 'O', ''),
#  (Alois, 'B', 'PERSON'),
#  (Hitler, 'I', 'PERSON'),
#  (., 'O', ''),
#  (The, 'O', ''),
#  (future, 'O', ''),
#  (Fuehrer, 'B', 'PERSON'),
#  ('s, 'O', ''),
#  (parent, 'O', ''),
#  (was, 'O', ''),
#  (originally, 'O', ''),
#  (a, 'O', ''),
#  (peasant, 'O', ''),
#  (,, 'O', ''),
#  (but, 'O', ''),
#  (later, 'O', ''),
#  (entered, 'O', ''),
#  (the, 'O', ''),
#  (Austrian, 'B', 'NORP'),
#  (customs, 'O', ''),
#  (service, 'O', ''),
#  (., 'O', ''),
#  (He, 'O', ''),
#  (was, 'O', ''),
#  (married, 'O', ''),
#  (three, 'B', 'CARDINAL'),
#  (times, 'O', ''),
#  (,, 'O', ''),
#  (his, 'O', ''),
#  (third, 'B', 'ORDINAL'),
#  (wife, 'O', ''),
#  (,, 'O', ''),
#  (who, 'O', ''),
#  (was, 'O', ''),
#  (also, 'O', ''),
#  (his, 'O', ''),
#  (niece, 'O', ''),
#  (and, 'O', ''),
#  (ward, 'O', ''),
#  (,, 'O', ''),
#  (being, 'O', ''),
#  (twenty, 'B', 'DATE'),
#  (years, 'I', 'DATE'),
#  (younger, 'O', ''),
#  (than, 'O', ''),
#  (her, 'O', ''),
#  (husband, 'O', ''),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (She, 'O', ''),
#  (was, 'O', ''),
#  (the, 'O', ''),
#  (future, 'O', ''),
#  (dictator, 'O', ''),
#  ('s, 'O', ''),
#  (mother, 'O', ''),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (Seven, 'B', 'CARDINAL'),
#  (children, 'O', ''),
#  (were, 'O', ''),
#  (born, 'O', ''),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (three, 'B', 'CARDINAL'),
#  (marriages, 'O', ''),
#  (contracted, 'O', ''),
#  (by, 'O', ''),
#  (Hitler, 'B', 'PERSON'),
#  ('s, 'O', ''),
#  (father, 'O', ''),
#  (,, 'O', ''),
#  (who, 'O', ''),
#  (died, 'O', ''),
#  (of, 'O', ''),
#  (pulmonary, 'O', ''),
#  (hemorrhage, 'O', ''),
#  (at, 'O', ''),
#  (the, 'B', 'DATE'),
#  (age, 'I', 'DATE'),
#  (of, 'I', 'DATE'),
#  (66, 'I', 'DATE'),
#  (., 'O', ''),
#  (His, 'O', ''),
#  (three, 'B', 'CARDINAL'),
#  (wives, 'O', ''),
#  (died, 'O', ''),
#  (of, 'O', ''),
#  (weak, 'O', ''),
#  (chests, 'O', ''),
#  (., 'O', ''),
#  (Two, 'B', 'CARDINAL'),
#  (of, 'O', ''),
#  (Hitler, 'B', 'PERSON'),
#  ('s, 'O', ''),
#  (brothers, 'O', ''),
#  (and, 'O', ''),
#  (a, 'O', ''),
#  (sister, 'O', ''),
#  (died, 'O', ''),
#  (in, 'O', ''),
#  (childhood, 'O', ''),
#  (., 'O', ''),
#  (A, 'O', ''),
#  (niece, 'O', ''),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (Fuehrer, 'B', 'ORG'),
#  (committed, 'O', ''),
#  (suicide, 'O', ''),
#  (., 'O', ''),
#  (A, 'O', ''),
#  (half, 'B', 'CARDINAL'),
#  (-, 'O', ''),
#  (brother, 'O', ''),
#  (had, 'O', ''),
#  (no, 'O', ''),
#  (progeny, 'O', ''),
#  (., 'O', ''),
#  (The, 'O', ''),
#  (German, 'B', 'NORP'),
#  (dictator, 'O', ''),
#  (himself, 'O', ''),
#  (never, 'O', ''),
#  (married, 'O', ''),
#  (., 'O', ''),
#  (At, 'O', ''),
#  (the, 'B', 'DATE'),
#  (age, 'I', 'DATE'),
#  (of, 'I', 'DATE'),
#  (16, 'I', 'DATE'),
#  (he, 'O', ''),
#  (suffered, 'O', ''),
#  (from, 'O', ''),
#  (lung, 'O', ''),
#  (trouble, 'O', ''),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (On, 'O', ''),
#  (his, 'O', ''),
#  (mother, 'O', ''),
#  ('s, 'O', ''),
#  (side, 'O', ''),
#  (there, 'O', ''),
#  (were, 'O', ''),
#  (several, 'O', ''),
#  (eccentrics, 'O', ''),
#  (in, 'O', ''),
#  (the, 'O', ''),
#  (family, 'O', ''),
#  (., 'O', ''),
#  (In, 'O', ''),
#  (general, 'O', ''),
#  (,, 'O', ''),
#  (the, 'O', ''),
#  (family, 'O', ''),
#  (showed, 'O', ''),
#  (definite, 'O', ''),
#  (tendencies, 'O', ''),
#  (to, 'O', ''),
#  (illness, 'O', ''),
#  (and, 'O', ''),
#  (mental, 'O', ''),
#  (instability, 'O', ''),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (German, 'O', ''),
#  (Adherent, 'O', ''),
#  (From, 'O', ''),
#  (Youth, 'O', ''),
#  (
#
#  , 'O', ''),
#  (Unlike, 'O', ''),
#  (his, 'O', ''),
#  (father, 'O', ''),
#  (,, 'O', ''),
#  (who, 'O', ''),
#  (was, 'O', ''),
#  (a, 'O', ''),
#  (fervent, 'O', ''),
#  (supporter, 'O', ''),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (Austro, 'B', 'PERSON'),
#  (-, 'O', ''),
#  (Hungarian, 'O', ''),
#  (monarchy, 'O', ''),
#  (and, 'O', ''),
#  (wanted, 'O', ''),
#  (his, 'O', ''),
#  (son, 'O', ''),
#  (to, 'O', ''),
#  (follow, 'O', ''),
#  (him, 'O', ''),
#  (in, 'O', ''),
#  (the, 'O', ''),
#  (Government, 'O', ''),
#  (service, 'O', ''),
#  (,, 'O', ''),
#  (Adolf, 'B', 'PERSON'),
#  (Hitler, 'I', 'PERSON'),
#  (was, 'O', ''),
#  (from, 'O', ''),
#  (early, 'O', ''),
#  (youth, 'O', ''),
#  (a, 'O', ''),
#  (strong, 'O', ''),
#  (adherent, 'O', ''),
#  (of, 'O', ''),
#  (Germany, 'B', 'GPE'),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (He, 'O', ''),
#  (was, 'O', ''),
#  (convinced, 'O', ''),
#  (that, 'O', ''),
#  (it, 'O', ''),
#  (was, 'O', ''),
#  (the, 'O', ''),
#  (historic, 'O', ''),
#  (mission, 'O', ''),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (Germans, 'B', 'NORP'),
#  (to, 'O', ''),
#  (rule, 'O', ''),
#  (the, 'O', ''),
#  (Austrians, 'B', 'NORP'),
#  (and, 'O', ''),
#  (the, 'O', ''),
#  (complex, 'O', ''),
#  (of, 'O', ''),
#  (races, 'O', ''),
#  (inhabiting, 'O', ''),
#  (Franz, 'B', 'PERSON'),
#  (Josef, 'I', 'PERSON'),
#  ('s, 'I', 'PERSON'),
#  (land, 'O', ''),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (Hitler, 'B', 'PERSON'),
#  (had, 'O', ''),
#  (no, 'O', ''),
#  (love, 'O', ''),
#  (for, 'O', ''),
#  (his, 'O', ''),
#  (father, 'O', ''),
#  (and, 'O', ''),
#  (resented, 'O', ''),
#  (his, 'O', ''),
#  (insistence, 'O', ''),
#  (that, 'O', ''),
#  (he, 'O', ''),
#  (prepare, 'O', ''),
#  (himself, 'O', ''),
#  (for, 'O', ''),
#  (the, 'O', ''),
#  (Government, 'O', ''),
#  (service, 'O', ''),
#  (., 'O', ''),
#  (Not, 'O', ''),
#  (venturing, 'O', ''),
#  (to, 'O', ''),
#  (defy, 'O', ''),
#  (his, 'O', ''),
#  (father, 'O', ''),
#  (openly, 'O', ''),
#  (,, 'O', ''),
#  (he, 'O', ''),
#  (adopted, 'O', ''),
#  (a, 'O', ''),
#  (policy, 'O', ''),
#  (of, 'O', ''),
#  (passive, 'O', ''),
#  (resistance, 'O', ''),
#  (by, 'O', ''),
#  (idling, 'O', ''),
#  (away, 'O', ''),
#  (his, 'O', ''),
#  (time, 'O', ''),
#  (at, 'O', ''),
#  (school, 'O', ''),
#  (., 'O', ''),
#  (At, 'O', ''),
#  (the, 'B', 'DATE'),
#  (age, 'I', 'DATE'),
#  (of, 'I', 'DATE'),
#  (14, 'I', 'DATE'),
#  (,, 'O', ''),
#  (after, 'O', ''),
#  (his, 'O', ''),
#  (father, 'O', ''),
#  ('s, 'O', ''),
#  (death, 'O', ''),
#  (,, 'O', ''),
#  (Hitler, 'B', 'PERSON'),
#  (went, 'O', ''),
#  (to, 'O', ''),
#  (live, 'O', ''),
#  (with, 'O', ''),
#  (his, 'O', ''),
#  (mother, 'O', ''),
#  (at, 'O', ''),
#  (Linz, 'B', 'PERSON'),
#  (., 'O', ''),
#  (There, 'O', ''),
#  (he, 'O', ''),
#  (stayed, 'O', ''),
#  (until, 'O', ''),
#  (he, 'O', ''),
#  (was, 'O', ''),
#  (19, 'B', 'DATE'),
#  (,, 'O', ''),
#  (pampered, 'O', ''),
#  (by, 'O', ''),
#  (his, 'O', ''),
#  (mother, 'O', ''),
#  (,, 'O', ''),
#  (who, 'O', ''),
#  (catered, 'O', ''),
#  (to, 'O', ''),
#  (his, 'O', ''),
#  (habit, 'O', ''),
#  (of, 'O', ''),
#  (idling, 'O', ''),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (Upon, 'O', ''),
#  (her, 'O', ''),
#  (death, 'O', ''),
#  (he, 'O', ''),
#  (found, 'O', ''),
#  (himself, 'O', ''),
#  (alone, 'O', ''),
#  (and, 'O', ''),
#  (friendless, 'O', ''),
#  (,, 'O', ''),
#  (without, 'O', ''),
#  (any, 'O', ''),
#  (means, 'O', ''),
#  (of, 'O', ''),
#  (earning, 'O', ''),
#  (a, 'O', ''),
#  (living, 'O', ''),
#  (and, 'O', ''),
#  (quite, 'O', ''),
#  (unprepared, 'O', ''),
#  (for, 'O', ''),
#  (the, 'O', ''),
#  (battle, 'O', ''),
#  (of, 'O', ''),
#  (life, 'O', ''),
#  (., 'O', ''),
#  (He, 'O', ''),
#  (had, 'O', ''),
#  (been, 'O', ''),
#  (a, 'O', ''),
#  (failure, 'O', ''),
#  (at, 'O', ''),
#  (school, 'O', ''),
#  (and, 'O', ''),
#  (was, 'O', ''),
#  (unable, 'O', ''),
#  (to, 'O', ''),
#  (pass, 'O', ''),
#  (examinations, 'O', ''),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (While, 'O', ''),
#  (his, 'O', ''),
#  (parents, 'O', ''),
#  (were, 'O', ''),
#  (still, 'O', ''),
#  (alive, 'O', ''),
#  (Hitler, 'B', 'PERSON'),
#  (had, 'O', ''),
#  (gone, 'O', ''),
#  (for, 'O', ''),
#  (a, 'O', ''),
#  (short, 'O', ''),
#  (time, 'O', ''),
#  (to, 'O', ''),
#  (Munich, 'B', 'GPE'),
#  (,, 'O', ''),
#  (where, 'O', ''),
#  (he, 'O', ''),
#  (had, 'O', ''),
#  (taken, 'O', ''),
#  (some, 'O', ''),
#  (courses, 'O', ''),
#  (in, 'O', ''),
#  (drawing, 'O', ''),
#  (., 'O', ''),
#  (With, 'O', ''),
#  (his, 'O', ''),
#  (mother, 'O', ''),
#  ('s, 'O', ''),
#  (passing, 'O', ''),
#  (he, 'O', ''),
#  (betook, 'O', ''),
#  (himself, 'O', ''),
#  (to, 'O', ''),
#  (Vienna, 'B', 'GPE'),
#  (,, 'O', ''),
#  (where, 'O', ''),
#  (he, 'O', ''),
#  (applied, 'O', ''),
#  (for, 'O', ''),
#  (admission, 'O', ''),
#  (to, 'O', ''),
#  (the, 'B', 'ORG'),
#  (Academy, 'I', 'ORG'),
#  (of, 'I', 'ORG'),
#  (Arts, 'I', 'ORG'),
#  (., 'O', ''),
#  (He, 'O', ''),
#  (thought, 'O', ''),
#  (of, 'O', ''),
#  (becoming, 'O', ''),
#  (an, 'O', ''),
#  (architect, 'O', ''),
#  (., 'O', ''),
#  (The, 'O', ''),
#  (few, 'O', ''),
#  (drawings, 'O', ''),
#  (he, 'O', ''),
#  (presented, 'O', ''),
#  (to, 'O', ''),
#  (the, 'O', ''),
#  (director, 'O', ''),
#  (were, 'O', ''),
#  (so, 'O', ''),
#  (mediocre, 'O', ''),
#  (,, 'O', ''),
#  (however, 'O', ''),
#  (,, 'O', ''),
#  (that, 'O', ''),
#  (his, 'O', ''),
#  (application, 'O', ''),
#  (was, 'O', ''),
#  (denied, 'O', ''),
#  (for, 'O', ''),
#  (lack, 'O', ''),
#  (of, 'O', ''),
#  (qualification, 'O', ''),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (From, 'O', ''),
#  (1909, 'B', 'DATE'),
#  (to, 'O', ''),
#  (the, 'O', ''),
#  (outbreak, 'O', ''),
#  (of, 'O', ''),
#  (the, 'B', 'EVENT'),
#  (First, 'I', 'EVENT'),
#  (World, 'I', 'EVENT'),
#  (War, 'I', 'EVENT'),
#  (,, 'O', ''),
#  (Hitler, 'B', 'PERSON'),
#  (led, 'O', ''),
#  (a, 'O', ''),
#  (wretched, 'O', ''),
#  (existence, 'O', ''),
#  (., 'O', ''),
#  (For, 'O', ''),
#  (a, 'O', ''),
#  (while, 'O', ''),
#  (he, 'O', ''),
#  (lived, 'O', ''),
#  (in, 'O', ''),
#  (a, 'O', ''),
#  (Vienna, 'B', 'GPE'),
#  (", 'O', ''),
#  (flophouse, 'O', ''),
#  (,, 'O', ''),
#  (", 'O', ''),
#  (among, 'O', ''),
#  (beggars, 'O', ''),
#  (and, 'O', ''),
#  (vagabonds, 'O', ''),
#  (., 'O', ''),
#  (He, 'O', ''),
#  (spent, 'O', ''),
#  (nights, 'B', 'TIME'),
#  (on, 'O', ''),
#  (park, 'O', ''),
#  (benches, 'O', ''),
#  (,, 'O', ''),
#  (harassed, 'O', ''),
#  (by, 'O', ''),
#  (the, 'O', ''),
#  (police, 'O', ''),
#  (., 'O', ''),
#  (He, 'O', ''),
#  (was, 'O', ''),
#  (an, 'O', ''),
#  (outcast, 'O', ''),
#  (among, 'O', ''),
#  (outcasts, 'O', ''),
#  (,, 'O', ''),
#  (eating, 'O', ''),
#  (at, 'O', ''),
#  (a, 'O', ''),
#  (monastery, 'O', ''),
#  (soup, 'O', ''),
#  (kitchen, 'O', ''),
#  (., 'O', ''),
#  (This, 'O', ''),
#  (existence, 'O', ''),
#  (continued, 'O', ''),
#  (for, 'O', ''),
#  (three, 'B', 'DATE'),
#  (years, 'I', 'DATE'),
#  (,, 'O', ''),
#  (during, 'O', ''),
#  (which, 'O', ''),
#  (he, 'O', ''),
#  (managed, 'O', ''),
#  (to, 'O', ''),
#  (earn, 'O', ''),
#  (a, 'O', ''),
#  (precarious, 'O', ''),
#  (living, 'O', ''),
#  (by, 'O', ''),
#  (painting, 'O', ''),
#  (picture, 'O', ''),
#  (postcards, 'O', ''),
#  (for, 'O', ''),
#  (tradesmen, 'O', ''),
#  (and, 'O', ''),
#  (doing, 'O', ''),
#  (minor, 'O', ''),
#  (carpenter, 'O', ''),
#  (work, 'O', ''),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (Nevertheless, 'O', ''),
#  (,, 'O', ''),
#  (he, 'O', ''),
#  (considered, 'O', ''),
#  (himself, 'O', ''),
#  (to, 'O', ''),
#  (be, 'O', ''),
#  (an, 'O', ''),
#  (artist, 'O', ''),
#  (of, 'O', ''),
#  (talent, 'O', ''),
#  (and, 'O', ''),
#  (hated, 'O', ''),
#  (the, 'O', ''),
#  (world, 'O', ''),
#  (for, 'O', ''),
#  (not, 'O', ''),
#  (according, 'O', ''),
#  (him, 'O', ''),
#  (recognition, 'O', ''),
#  (., 'O', ''),
#  (He, 'O', ''),
#  (spent, 'O', ''),
#  (his, 'O', ''),
#  (leisure, 'O', ''),
#  (hours, 'O', ''),
#  (day, 'O', ''),
#  (-, 'O', ''),
#  (dreaming, 'O', ''),
#  (and, 'O', ''),
#  (brooding, 'O', ''),
#  (over, 'O', ''),
#  (his, 'O', ''),
#  (frustration, 'O', ''),
#  (., 'O', ''),
#  (He, 'O', ''),
#  (himself, 'O', ''),
#  (admitted, 'O', ''),
#  (in, 'O', ''),
#  (his, 'O', ''),
#  (autobiography, 'O', ''),
#  (that, 'O', ''),
#  (up, 'O', ''),
#  (to, 'O', ''),
#  (his, 'O', ''),
#  (twenty, 'B', 'DATE'),
#  (-, 'I', 'DATE'),
#  (fifth, 'I', 'DATE'),
#  (year, 'I', 'DATE'),
#  (he, 'O', ''),
#  (was, 'O', ''),
#  (what, 'O', ''),
#  (is, 'O', ''),
#  (known, 'O', ''),
#  (as, 'O', ''),
#  (a, 'O', ''),
#  (good, 'O', ''),
#  (-, 'O', ''),
#  (for, 'O', ''),
#  (-, 'O', ''),
#  (nothing, 'O', ''),
#  (,, 'O', ''),
#  (a, 'O', ''),
#  (spoiled, 'O', ''),
#  (idler, 'O', ''),
#  (., 'O', ''),
#  (Moved, 'O', ''),
#  (by, 'O', ''),
#  (a, 'O', ''),
#  (sensitive, 'O', ''),
#  (ego, 'O', ''),
#  (,, 'O', ''),
#  (a, 'O', ''),
#  (restless, 'O', ''),
#  (spirit, 'O', ''),
#  (and, 'O', ''),
#  (a, 'O', ''),
#  (quick, 'O', ''),
#  (mind, 'O', ''),
#  (,, 'O', ''),
#  (he, 'O', ''),
#  (yearned, 'O', ''),
#  (passionately, 'O', ''),
#  (to, 'O', ''),
#  (make, 'O', ''),
#  (an, 'O', ''),
#  (impression, 'O', ''),
#  (,, 'O', ''),
#  (to, 'O', ''),
#  (gain, 'O', ''),
#  (recognition, 'O', ''),
#  (,, 'O', ''),
#  (to, 'O', ''),
#  (attain, 'O', ''),
#  (to, 'O', ''),
#  (great, 'O', ''),
#  (achievements, 'O', ''),
#  (,, 'O', ''),
#  (to, 'O', ''),
#  (know, 'O', ''),
#  (everything, 'O', ''),
#  (,, 'O', ''),
#  (to, 'O', ''),
#  (attract, 'O', ''),
#  (attention, 'O', ''),
#  (,, 'O', ''),
#  (to, 'O', ''),
#  (master, 'O', ''),
#  (the, 'O', ''),
#  (world, 'O', ''),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (Politics, 'O', ''),
#  (His, 'O', ''),
#  (Ruling, 'O', ''),
#  (Passion, 'O', ''),
#  (
#
#  , 'O', ''),
#  (His, 'O', ''),
#  (greatest, 'O', ''),
#  (passion, 'O', ''),
#  (was, 'O', ''),
#  (for, 'O', ''),
#  (politics, 'O', ''),
#  (., 'O', ''),
#  (A, 'O', ''),
#  (shy, 'O', ''),
#  (and, 'O', ''),
#  (beaten, 'O', ''),
#  (youth, 'O', ''),
#  (,, 'O', ''),
#  (Hitler, 'B', 'PERSON'),
#  (would, 'O', ''),
#  (become, 'O', ''),
#  (transformed, 'O', ''),
#  (as, 'O', ''),
#  (soon, 'O', ''),
#  (as, 'O', ''),
#  (conversation, 'O', ''),
#  (turned, 'O', ''),
#  (on, 'O', ''),
#  (matters, 'O', ''),
#  (political, 'O', ''),
#  (., 'O', ''),
#  (His, 'O', ''),
#  (tongue, 'O', ''),
#  (would, 'O', ''),
#  (loosen, 'O', ''),
#  (and, 'O', ''),
#  (a, 'O', ''),
#  (torrent, 'O', ''),
#  (of, 'O', ''),
#  (words, 'O', ''),
#  (would, 'O', ''),
#  (rush, 'O', ''),
#  (from, 'O', ''),
#  (his, 'O', ''),
#  (lips, 'O', ''),
#  (., 'O', ''),
#  (In, 'O', ''),
#  (those, 'B', 'DATE'),
#  (days, 'I', 'DATE'),
#  (before, 'O', ''),
#  (the, 'B', 'EVENT'),
#  (First, 'I', 'EVENT'),
#  (World, 'I', 'EVENT'),
#  (War, 'I', 'EVENT'),
#  (Hitler, 'I', 'EVENT'),
#  (never, 'O', ''),
#  (formed, 'O', ''),
#  (friendships, 'O', ''),
#  (,, 'O', ''),
#  (male, 'O', ''),
#  (or, 'O', ''),
#  (female, 'O', ''),
#  (., 'O', ''),
#  (He, 'O', ''),
#  (never, 'O', ''),
#  (communicated, 'O', ''),
#  (with, 'O', ''),
#  (his, 'O', ''),
#  (family, 'O', ''),
#  (,, 'O', ''),
#  (who, 'O', ''),
#  (thought, 'O', ''),
#  (him, 'O', ''),
#  (dead, 'O', ''),
#  (., 'O', ''),
#  (Jeered, 'O', ''),
#  (at, 'O', ''),
#  (by, 'O', ''),
#  (acquaintances, 'O', ''),
#  (,, 'O', ''),
#  (he, 'O', ''),
#  (wept, 'O', ''),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (The, 'O', ''),
#  (one, 'B', 'CARDINAL'),
#  (thing, 'O', ''),
#  (that, 'O', ''),
#  (gave, 'O', ''),
#  (him, 'O', ''),
#  (hope, 'O', ''),
#  (and, 'O', ''),
#  (courage, 'O', ''),
#  (was, 'O', ''),
#  (the, 'O', ''),
#  (disintegration, 'O', ''),
#  (of, 'O', ''),
#  (the, 'B', 'GPE'),
#  (Austro-, 'I', 'GPE'),
#  (Hungarian, 'I', 'GPE'),
#  (Empire, 'I', 'GPE'),
#  (,, 'O', ''),
#  (which, 'O', ''),
#  (he, 'O', ''),
#  (foresaw, 'O', ''),
#  (,, 'O', ''),
#  (and, 'O', ''),
#  (evidences, 'O', ''),
#  (of, 'O', ''),
#  (which, 'O', ''),
#  (had, 'O', ''),
#  (become, 'O', ''),
#  (apparent, 'O', ''),
#  (to, 'O', ''),
#  (many, 'O', ''),
#  (long, 'O', ''),
#  (before, 'O', ''),
#  (the, 'O', ''),
#  (war, 'O', ''),
#  (., 'O', ''),
#  (Considering, 'O', ''),
#  (himself, 'O', ''),
#  (a, 'O', ''),
#  (German, 'B', 'NORP'),
#  (,, 'O', ''),
#  (he, 'O', ''),
#  (felt, 'O', ''),
#  (superior, 'O', ''),
#  (to, 'O', ''),
#  (those, 'O', ''),
#  (around, 'O', ''),
#  (him, 'O', ''),
#  (., 'O', ''),
#  (For, 'O', ''),
#  (the, 'O', ''),
#  (Slavs, 'B', 'NORP'),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (empire, 'O', ''),
#  (he, 'O', ''),
#  (felt, 'O', ''),
#  (contempt, 'O', ''),
#  (., 'O', ''),
#  (For, 'O', ''),
#  (the, 'O', ''),
#  (Jews, 'B', 'NORP'),
#  (he, 'O', ''),
#  (felt, 'O', ''),
#  (hatred, 'O', ''),
#  (., 'O', ''),
#  (As, 'O', ''),
#  (for, 'O', ''),
#  (the, 'O', ''),
#  (workers, 'O', ''),
#  (,, 'O', ''),
#  (he, 'O', ''),
#  (believed, 'O', ''),
#  (them, 'O', ''),
#  (to, 'O', ''),
#  (be, 'O', ''),
#  (not, 'O', ''),
#  (much, 'O', ''),
#  (better, 'O', ''),
#  (., 'O', ''),
#  (This, 'O', ''),
#  (feeling, 'O', ''),
#  (he, 'O', ''),
#  (expressed, 'O', ''),
#  (to, 'O', ''),
#  (Otto, 'B', 'PERSON'),
#  (Strasser, 'I', 'PERSON'),
#  (,, 'O', ''),
#  (one, 'O', ''),
#  (of, 'O', ''),
#  (his, 'O', ''),
#  (early, 'O', ''),
#  (collaborators, 'O', ''),
#  (in, 'O', ''),
#  (the, 'O', ''),
#  (Nazi, 'B', 'NORP'),
#  (movement, 'O', ''),
#  (,, 'O', ''),
#  (in, 'O', ''),
#  (1930, 'B', 'DATE'),
#  (,, 'O', ''),
#  (when, 'O', ''),
#  (he, 'O', ''),
#  (said, 'O', ''),
#  (:, 'O', ''),
#  (", 'O', ''),
#  (The, 'O', ''),
#  (workers, 'O', ''),
#  (,, 'O', ''),
#  (they, 'O', ''),
#  (want, 'O', ''),
#  (nothing, 'O', ''),
#  (but, 'O', ''),
#  (bread, 'O', ''),
#  (and, 'O', ''),
#  (games, 'O', ''),
#  (., 'O', ''),
#  (In, 'O', ''),
#  (the, 'O', ''),
#  (great, 'O', ''),
#  (mass, 'O', ''),
#  (they, 'O', ''),
#  (are, 'O', ''),
#  (not, 'O', ''),
#  (worth, 'O', ''),
#  (consideration, 'O', ''),
#  (., 'O', ''),
#  (We, 'O', ''),
#  (must, 'O', ''),
#  (build, 'O', ''),
#  (a, 'O', ''),
#  (master, 'O', ''),
#  (class, 'O', ''),
#  (from, 'O', ''),
#  (elements, 'O', ''),
#  (of, 'O', ''),
#  (a, 'O', ''),
#  (better, 'O', ''),
#  (race, 'O', ''),
#  (., 'O', ''),
#  (", 'O', ''),
#  (
#
#  , 'O', ''),
#  (And, 'O', ''),
#  (it, 'O', ''),
#  (was, 'O', ''),
#  (he, 'O', ''),
#  (who, 'O', ''),
#  (would, 'O', ''),
#  (build, 'O', ''),
#  (that, 'O', ''),
#  (master, 'O', ''),
#  (class, 'O', ''),
#  (and, 'O', ''),
#  (lead, 'O', ''),
#  (it, 'O', ''),
#  (!, 'O', ''),
#  (In, 'O', ''),
#  (addition, 'O', ''),
#  (to, 'O', ''),
#  (dividing, 'O', ''),
#  (mankind, 'O', ''),
#  (into, 'O', ''),
#  (inferior, 'O', ''),
#  (and, 'O', ''),
#  (superior, 'O', ''),
#  (races, 'O', ''),
#  (,, 'O', ''),
#  (he, 'O', ''),
#  (divided, 'O', ''),
#  (it, 'O', ''),
#  (also, 'O', ''),
#  (into, 'O', ''),
#  (inferior, 'O', ''),
#  (and, 'O', ''),
#  (superior, 'O', ''),
#  (human, 'O', ''),
#  (beings, 'O', ''),
#  (., 'O', ''),
#  (He, 'O', ''),
#  (stood, 'O', ''),
#  (out, 'O', ''),
#  (in, 'O', ''),
#  (his, 'O', ''),
#  (classification, 'O', ''),
#  (as, 'O', ''),
#  (the, 'O', ''),
#  (superman, 'O', ''),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (Long, 'O', ''),
#  (before, 'O', ''),
#  (he, 'O', ''),
#  (had, 'O', ''),
#  (dreamed, 'O', ''),
#  (of, 'O', ''),
#  (achieving, 'O', ''),
#  (power, 'O', ''),
#  (he, 'O', ''),
#  (had, 'O', ''),
#  (developed, 'O', ''),
#  (the, 'O', ''),
#  (principles, 'O', ''),
#  (that, 'O', ''),
#  (nations, 'O', ''),
#  (were, 'O', ''),
#  (destined, 'O', ''),
#  (to, 'O', ''),
#  (hate, 'O', ''),
#  (,, 'O', ''),
#  (oppose, 'O', ''),
#  (and, 'O', ''),
#  (destroy, 'O', ''),
#  (one, 'O', ''),
#  (another, 'O', ''),
#  (;, 'O', ''),
#  (that, 'O', ''),
#  (the, 'O', ''),
#  (law, 'O', ''),
#  (of, 'O', ''),
#  (history, 'O', ''),
#  (was, 'O', ''),
#  (the, 'O', ''),
#  (struggle, 'O', ''),
#  (for, 'O', ''),
#  (survival, 'O', ''),
#  (between, 'O', ''),
#  (peoples, 'O', ''),
#  (;, 'O', ''),
#  (that, 'O', ''),
#  (the, 'O', ''),
#  (Germans, 'B', 'NORP'),
#  (were, 'O', ''),
#  (chosen, 'O', ''),
#  (by, 'O', ''),
#  (destiny, 'O', ''),
#  (to, 'O', ''),
#  (rule, 'O', ''),
#  (over, 'O', ''),
#  (others, 'O', ''),
#  (,, 'O', ''),
# ...
#  (her, 'O', ''),
#  (as, 'O', ''),
#  (a, 'O', ''),
#  (favorite, 'O', ''),
#  (and, 'O', ''),
#  (for, 'O', ''),
#  (a, 'O', ''),
#  (long, 'O', ''),
#  (time, 'O', ''),
#  (regularly, 'O', ''),
#  (took, 'O', ''),
#  (tea, 'O', ''),
#  (with, 'O', ''),
#  (her, 'O', ''),
#  (at, 'O', ''),
#  (her, 'O', ''),
#  (Berlin, 'B', 'GPE'),
#  (home, 'O', ''),
#  (every, 'O', ''),
#  (fortnight, 'O', ''),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (As, 'O', ''),
#  (a, 'O', ''),
#  (youth, 'O', ''),
#  (Hitler, 'B', 'PERSON'),
#  (developed, 'O', ''),
#  (a, 'O', ''),
#  (passion, 'O', ''),
#  (for, 'O', ''),
#  (Wagnerian, 'B', 'NORP'),
#  (music, 'O', ''),
#  (., 'O', ''),
#  (In, 'O', ''),
#  (Munich, 'B', 'GPE'),
#  (,, 'O', ''),
#  (where, 'O', ''),
#  (he, 'O', ''),
#  (laid, 'O', ''),
#  (the, 'O', ''),
#  (foundations, 'O', ''),
#  (of, 'O', ''),
#  (his, 'O', ''),
#  (movement, 'O', ''),
#  (,, 'O', ''),
#  (he, 'O', ''),
#  (met, 'O', ''),
#  (Frau, 'B', 'PERSON'),
#  (Winifred, 'I', 'PERSON'),
#  (Wagner, 'I', 'PERSON'),
#  (,, 'O', ''),
#  (widow, 'O', ''),
#  (of, 'O', ''),
#  (Siegfried, 'B', 'ORG'),
#  (Wagner, 'I', 'ORG'),
#  (,, 'O', ''),
#  (the, 'O', ''),
#  (composer, 'O', ''),
#  ('s, 'O', ''),
#  (son, 'O', ''),
#  (., 'O', ''),
#  (Frau, 'B', 'PERSON'),
#  (
#
#  , 'I', 'PERSON'),
#  (Wagner, 'I', 'PERSON'),
#  (became, 'O', ''),
#  (an, 'O', ''),
#  (enthusiastic, 'O', ''),
#  (Hitlerite, 'B', 'PERSON'),
#  (and, 'O', ''),
#  (this, 'O', ''),
#  (,, 'O', ''),
#  (together, 'O', ''),
#  (with, 'O', ''),
#  (Hitler, 'B', 'PERSON'),
#  ('s, 'O', ''),
#  (devotion, 'O', ''),
#  (to, 'O', ''),
#  (Wagner, 'B', 'PERSON'),
#  (,, 'O', ''),
#  (made, 'O', ''),
#  (them, 'O', ''),
#  (fast, 'O', ''),
#  (friends, 'O', ''),
#  (., 'O', ''),
#  (At, 'O', ''),
#  (one, 'B', 'CARDINAL'),
#  (time, 'O', ''),
#  (there, 'O', ''),
#  (were, 'O', ''),
#  (reports, 'O', ''),
#  (that, 'O', ''),
#  (they, 'O', ''),
#  (would, 'O', ''),
#  (marry, 'O', ''),
#  (,, 'O', ''),
#  (but, 'O', ''),
#  (these, 'O', ''),
#  (were, 'O', ''),
#  (denied, 'O', ''),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (Perhaps, 'O', ''),
#  (because, 'O', ''),
#  (of, 'O', ''),
#  (these, 'O', ''),
#  (reports, 'O', ''),
#  (Hitler, 'B', 'PERSON'),
#  (drew, 'O', ''),
#  (away, 'O', ''),
#  (from, 'O', ''),
#  (her, 'O', ''),
#  (., 'O', ''),
#  (To, 'O', ''),
#  (Frau, 'B', 'PERSON'),
#  (Wagner, 'I', 'PERSON'),
#  (,, 'O', ''),
#  (however, 'O', ''),
#  (,, 'O', ''),
#  (he, 'O', ''),
#  (owed, 'O', ''),
#  (much, 'O', ''),
#  (of, 'O', ''),
#  (his, 'O', ''),
#  (early, 'O', ''),
#  (financial, 'O', ''),
#  (aid, 'O', ''),
#  (., 'O', ''),
#  (She, 'O', ''),
#  (was, 'O', ''),
#  (not, 'O', ''),
#  (wealthy, 'O', ''),
#  (,, 'O', ''),
#  (but, 'O', ''),
#  (because, 'O', ''),
#  (of, 'O', ''),
#  (her, 'O', ''),
#  (social, 'O', ''),
#  (position, 'O', ''),
#  (she, 'O', ''),
#  (was, 'O', ''),
#  (able, 'O', ''),
#  (to, 'O', ''),
#  (raise, 'O', ''),
#  (considerable, 'O', ''),
#  (sums, 'O', ''),
#  (for, 'O', ''),
#  (the, 'O', ''),
#  (Nazi, 'B', 'NORP'),
#  (movement, 'O', ''),
#  (when, 'O', ''),
#  (Hitler, 'B', 'PERSON'),
#  (most, 'O', ''),
#  (needed, 'O', ''),
#  (money, 'O', ''),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (Another, 'O', ''),
#  (woman, 'O', ''),
#  (who, 'O', ''),
#  (had, 'O', ''),
#  (his, 'O', ''),
#  (favor, 'O', ''),
#  (was, 'O', ''),
#  (Leni, 'B', 'PERSON'),
#  (Riefenstahl, 'I', 'PERSON'),
#  (,, 'O', ''),
#  (a, 'O', ''),
#  (former, 'O', ''),
#  (movie, 'O', ''),
#  (actress, 'O', ''),
#  (,, 'O', ''),
#  (whom, 'O', ''),
#  (he, 'O', ''),
#  (entrusted, 'O', ''),
#  (with, 'O', ''),
#  (the, 'O', ''),
#  (task, 'O', ''),
#  (of, 'O', ''),
#  (editing, 'O', ''),
#  (the, 'O', ''),
#  (propaganda, 'O', ''),
#  (film, 'O', ''),
#  (", 'O', ''),
#  (The, 'B', 'WORK_OF_ART'),
#  (Triumph, 'I', 'WORK_OF_ART'),
#  (of, 'I', 'WORK_OF_ART'),
#  (Will, 'I', 'WORK_OF_ART'),
#  (,, 'O', ''),
#  (", 'O', ''),
#  (the, 'O', ''),
#  (photographing, 'O', ''),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (1935, 'B', 'DATE'),
#  (Olympic, 'B', 'EVENT'),
#  (Games, 'I', 'EVENT'),
#  (in, 'O', ''),
#  (Berlin, 'B', 'GPE'),
#  (and, 'O', ''),
#  (various, 'O', ''),
#  (Nazi, 'B', 'NORP'),
#  (meetings, 'O', ''),
#  (and, 'O', ''),
#  (spectacles, 'O', ''),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (English, 'O', ''),
#  (Women, 'O', ''),
#  (His, 'O', ''),
#  (Friends, 'O', ''),
#  (
#
#  , 'O', ''),
#  (There, 'O', ''),
#  (were, 'O', ''),
#  (also, 'O', ''),
#  (two, 'B', 'CARDINAL'),
#  (English, 'B', 'LANGUAGE'),
#  (women, 'O', ''),
#  (who, 'O', ''),
#  (were, 'O', ''),
#  (his, 'O', ''),
#  (friends, 'O', ''),
#  (,, 'O', ''),
#  (the, 'O', ''),
#  (daughters, 'O', ''),
#  (of, 'O', ''),
#  (Lord, 'B', 'PERSON'),
#  (Redesdale, 'I', 'PERSON'),
#  (--, 'O', ''),
#  (the, 'O', ''),
#  (Hon, 'B', 'ORG'),
#  (., 'O', ''),
#  (Diana, 'B', 'PERSON'),
#  (Freeman, 'I', 'PERSON'),
#  (-, 'I', 'PERSON'),
#  (Mitford, 'I', 'PERSON'),
#  (,, 'O', ''),
#  (a, 'O', ''),
#  (supporter, 'O', ''),
#  (of, 'O', ''),
#  (Sir, 'O', ''),
#  (Oswald, 'B', 'PERSON'),
#  (Mosley, 'I', 'PERSON'),
#  ('s, 'I', 'PERSON'),
#  (Blackshirts, 'B', 'GPE'),
#  (in, 'O', ''),
#  (England, 'B', 'GPE'),
#  (,, 'O', ''),
#  (and, 'O', ''),
#  (the, 'O', ''),
#  (Hon, 'B', 'ORG'),
#  (., 'O', ''),
#  (Unity, 'O', ''),
#  (
#
#  , 'O', ''),
#  (Freeman, 'O', ''),
#  (-, 'O', ''),
#  (Mitford, 'O', ''),
#  (., 'O', ''),
#  (The, 'O', ''),
#  (latter, 'O', ''),
#  (was, 'O', ''),
#  (Hitler, 'B', 'PERSON'),
#  ('s, 'O', ''),
#  (favorite, 'O', ''),
#  (and, 'O', ''),
#  (they, 'O', ''),
#  (often, 'O', ''),
#  (lunched, 'O', ''),
#  (together, 'O', ''),
#  (in, 'O', ''),
#  (Munich, 'B', 'GPE'),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (Frau, 'O', ''),
#  (Victoria, 'B', 'PERSON'),
#  (Ursuleac, 'I', 'PERSON'),
#  (,, 'O', ''),
#  (a, 'O', ''),
#  (member, 'O', ''),
#  (of, 'O', ''),
#  (the, 'B', 'FAC'),
#  (Berlin, 'I', 'FAC'),
#  (Opera, 'I', 'FAC'),
#  (,, 'O', ''),
#  (also, 'O', ''),
#  (enjoyed, 'O', ''),
#  (Hitler, 'B', 'PERSON'),
#  ('s, 'O', ''),
#  (friendship, 'O', ''),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (Hitler, 'B', 'PERSON'),
#  (liked, 'O', ''),
#  (well, 'O', ''),
#  (-, 'O', ''),
#  (dressed, 'O', ''),
#  (women, 'O', ''),
#  (and, 'O', ''),
#  (admired, 'O', ''),
#  (French, 'B', 'NORP'),
#  (styles, 'O', ''),
#  (., 'O', ''),
#  (On, 'O', ''),
#  (one, 'B', 'CARDINAL'),
#  (occasion, 'O', ''),
#  (he, 'O', ''),
#  (scotched, 'O', ''),
#  (a, 'O', ''),
#  (movement, 'O', ''),
#  (launched, 'O', ''),
#  (by, 'O', ''),
#  (Frau, 'B', 'PERSON'),
#  (Joseph, 'I', 'PERSON'),
#  (Goebbels, 'I', 'PERSON'),
#  (,, 'O', ''),
#  (wife, 'O', ''),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (Minister, 'O', ''),
#  (of, 'O', ''),
#  (Propaganda, 'B', 'ORG'),
#  (and, 'I', 'ORG'),
#  (Enlightenment, 'I', 'ORG'),
#  (,, 'O', ''),
#  (for, 'O', ''),
#  (a, 'O', ''),
#  (boycott, 'O', ''),
#  (on, 'O', ''),
#  (French, 'B', 'NORP'),
#  (dress, 'O', ''),
#  (models, 'O', ''),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (Hitler, 'O', ''),
#  (detested, 'O', ''),
#  (evening, 'O', ''),
#  (clothes, 'O', ''),
#  (and, 'O', ''),
#  (wore, 'O', ''),
#  (full, 'O', ''),
#  (dress, 'O', ''),
#  (only, 'O', ''),
#  (on, 'O', ''),
#  (rare, 'O', ''),
#  (visits, 'O', ''),
#  (to, 'O', ''),
#  (the, 'O', ''),
#  (opera, 'O', ''),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (Though, 'O', ''),
#  (merciless, 'O', ''),
#  (to, 'O', ''),
#  (political, 'O', ''),
#  (opponents, 'O', ''),
#  (,, 'O', ''),
#  (he, 'O', ''),
#  (was, 'O', ''),
#  (kind, 'O', ''),
#  (to, 'O', ''),
#  (animals, 'O', ''),
#  (., 'O', ''),
#  (A, 'O', ''),
#  (militarist, 'O', ''),
#  (,, 'O', ''),
#  (he, 'O', ''),
#  (was, 'O', ''),
#  (sickened, 'O', ''),
#  (by, 'O', ''),
#  (the, 'O', ''),
#  (sight, 'O', ''),
#  (of, 'O', ''),
#  (blood, 'O', ''),
#  (., 'O', ''),
#  (A, 'O', ''),
#  (Wagnerian, 'B', 'NORP'),
#  (mystic, 'O', ''),
#  (,, 'O', ''),
#  (he, 'O', ''),
#  (loved, 'O', ''),
#  (spectacles, 'O', ''),
#  (of, 'O', ''),
#  (heroics, 'O', ''),
#  (and, 'O', ''),
#  (death, 'O', ''),
#  (., 'O', ''),
#  (He, 'O', ''),
#  (was, 'O', ''),
#  (simple, 'O', ''),
#  (,, 'O', ''),
#  (Spartan, 'B', 'NORP'),
#  (and, 'O', ''),
#  (vain, 'O', ''),
#  (to, 'O', ''),
#  (the, 'O', ''),
#  (point, 'O', ''),
#  (of, 'O', ''),
#  (megalomania, 'B', 'GPE'),
#  (., 'O', ''),
#  (While, 'O', ''),
#  (he, 'O', ''),
#  (took, 'O', ''),
#  (good, 'O', ''),
#  (care, 'O', ''),
#  (of, 'O', ''),
#  (his, 'O', ''),
#  (loyal, 'O', ''),
#  (lieutenants, 'O', ''),
#  (he, 'O', ''),
#  (had, 'O', ''),
#  (no, 'O', ''),
#  (real, 'O', ''),
#  (loyalty, 'O', ''),
#  (to, 'O', ''),
#  (anyone, 'O', ''),
#  (,, 'O', ''),
#  (and, 'O', ''),
#  (in, 'O', ''),
#  (his, 'O', ''),
#  (party, 'O', ''),
#  (he, 'O', ''),
#  (knew, 'O', ''),
#  (how, 'O', ''),
#  (to, 'O', ''),
#  (thwart, 'O', ''),
#  (opposition, 'O', ''),
#  (by, 'O', ''),
#  (setting, 'O', ''),
#  (friends, 'O', ''),
#  (against, 'O', ''),
#  (one, 'O', ''),
#  (another, 'O', ''),
#  (., 'O', ''),
#  (His, 'O', ''),
#  (enemies, 'O', ''),
#  (he, 'O', ''),
#  (suppressed, 'O', ''),
#  (ruthlessly, 'O', ''),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (While, 'O', ''),
#  (endowed, 'O', ''),
#  (with, 'O', ''),
#  (vast, 'O', ''),
#  (energy, 'O', ''),
#  (,, 'O', ''),
#  (he, 'O', ''),
#  (was, 'O', ''),
#  (a, 'O', ''),
#  (procrastinator, 'O', ''),
#  (in, 'O', ''),
#  (minor, 'O', ''),
#  (matters, 'O', ''),
#  (and, 'O', ''),
#  (was, 'O', ''),
#  (given, 'O', ''),
#  (to, 'O', ''),
#  (hasty, 'O', ''),
#  (decisions, 'O', ''),
#  (on, 'O', ''),
#  (important, 'O', ''),
#  (things, 'O', ''),
#  (., 'O', ''),
#  (He, 'O', ''),
#  (talked, 'O', ''),
#  (with, 'O', ''),
#  (great, 'O', ''),
#  (rapidity, 'O', ''),
#  (., 'O', ''),
#  (An, 'O', ''),
#  (interviewer, 'O', ''),
#  (usually, 'O', ''),
#  (found, 'O', ''),
#  (that, 'O', ''),
#  (it, 'O', ''),
#  (was, 'O', ''),
#  (himself, 'O', ''),
#  (who, 'O', ''),
#  (was, 'O', ''),
#  (being, 'O', ''),
#  (interviewed, 'O', ''),
#  (., 'O', ''),
#  (While, 'O', ''),
#  (pretending, 'O', ''),
#  (to, 'O', ''),
#  (listen, 'O', ''),
#  (to, 'O', ''),
#  (advice, 'O', ''),
#  (,, 'O', ''),
#  (Hitler, 'B', 'PERSON'),
#  (always, 'O', ''),
#  (made, 'O', ''),
#  (his, 'O', ''),
#  (own, 'O', ''),
#  (decisions, 'O', ''),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (He, 'O', ''),
#  (read, 'O', ''),
#  (little, 'O', ''),
#  (,, 'O', ''),
#  (although, 'O', ''),
#  (he, 'O', ''),
#  (possessed, 'O', ''),
#  (a, 'O', ''),
#  (library, 'O', ''),
#  (of, 'O', ''),
#  (6,000, 'B', 'CARDINAL'),
#  (volumes, 'O', ''),
#  (., 'O', ''),
#  (His, 'O', ''),
#  (outbursts, 'O', ''),
#  (of, 'O', ''),
#  (furious, 'O', ''),
#  (energy, 'O', ''),
#  (would, 'O', ''),
#  (be, 'O', ''),
#  (preceded, 'O', ''),
#  (by, 'O', ''),
#  (long, 'O', ''),
#  (periods, 'O', ''),
#  (of, 'O', ''),
#  (indolence, 'O', ''),
#  (., 'O', ''),
#  (When, 'O', ''),
#  (roused, 'O', ''),
#  (to, 'O', ''),
#  (anger, 'O', ''),
#  (he, 'O', ''),
#  (became, 'O', ''),
#  (dangerous, 'O', ''),
#  (,, 'O', ''),
#  (even, 'O', ''),
#  (for, 'O', ''),
#  (his, 'O', ''),
#  (close, 'O', ''),
#  (associates, 'O', ''),
#  (., 'O', ''),
#  (He, 'O', ''),
#  (brooked, 'O', ''),
#  (no, 'O', ''),
#  (contradiction, 'O', ''),
#  (., 'O', ''),
#  (His, 'O', ''),
#  (neurasthenia, 'B', 'ORG'),
#  (frequently, 'O', ''),
#  (drove, 'O', ''),
#  (him, 'O', ''),
#  (to, 'O', ''),
#  (tears, 'O', ''),
#  (and, 'O', ''),
#  (hysterics, 'O', ''),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (Hitler, 'O', ''),
#  (was, 'O', ''),
#  (truly, 'O', ''),
#  (devoted, 'O', ''),
#  (to, 'O', ''),
#  (music, 'O', ''),
#  (not, 'O', ''),
#  (only, 'O', ''),
#  (as, 'O', ''),
#  (an, 'O', ''),
#  (art, 'O', ''),
#  (but, 'O', ''),
#  (as, 'O', ''),
#  (a, 'O', ''),
#  (tonic, 'O', ''),
#  (for, 'O', ''),
#  (his, 'O', ''),
#  (nerves, 'O', ''),
#  (., 'O', ''),
#  (His, 'O', ''),
#  (favorites, 'O', ''),
#  (were, 'O', ''),
#  (Schubert, 'B', 'PERSON'),
#  (,, 'O', ''),
#  (Beethoven, 'B', 'PERSON'),
#  (and, 'O', ''),
#  (Wagner, 'B', 'PERSON'),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (One, 'O', ''),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (many, 'O', ''),
#  (disappointments, 'O', ''),
#  (of, 'O', ''),
#  (his, 'O', ''),
#  (youth, 'O', ''),
#  (was, 'O', ''),
#  (his, 'O', ''),
#  (rejection, 'O', ''),
#  (by, 'O', ''),
#  (the, 'B', 'ORG'),
#  (Vienna, 'I', 'ORG'),
#  (Academy, 'I', 'ORG'),
#  (when, 'O', ''),
#  (he, 'O', ''),
#  (applied, 'O', ''),
#  (for, 'O', ''),
#  (admittance, 'O', ''),
#  (to, 'O', ''),
#  (study, 'O', ''),
#  (art, 'O', ''),
#  (and, 'O', ''),
#  (architecture, 'O', ''),
#  (., 'O', ''),
#  (He, 'O', ''),
#  (found, 'O', ''),
#  (satisfaction, 'O', ''),
#  (for, 'O', ''),
#  (this, 'O', ''),
#  (rebuff, 'O', ''),
#  (as, 'O', ''),
#  (leader, 'O', ''),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (Nazi, 'B', 'NORP'),
#  (party, 'O', ''),
#  (when, 'O', ''),
#  (he, 'O', ''),
#  (supervised, 'O', ''),
#  (the, 'O', ''),
#  (plans, 'O', ''),
#  (for, 'O', ''),
#  (the, 'B', 'ORG'),
#  (Brown, 'I', 'ORG'),
#  (
#
#  , 'I', 'ORG'),
#  (House, 'I', 'ORG'),
#  (in, 'O', ''),
#  (Munich, 'B', 'GPE'),
#  (,, 'O', ''),
#  (party, 'O', ''),
#  (headquarters, 'O', ''),
#  (., 'O', ''),
#  (He, 'O', ''),
#  (also, 'O', ''),
#  (interfered, 'O', ''),
#  (much, 'O', ''),
#  (in, 'O', ''),
#  (the, 'O', ''),
#  (designing, 'O', ''),
#  (of, 'O', ''),
#  (new, 'O', ''),
#  (museums, 'O', ''),
#  (and, 'O', ''),
#  (Government, 'O', ''),
#  (buildings, 'O', ''),
#  (., 'O', ''),
#  (To, 'O', ''),
#  (show, 'O', ''),
#  (his, 'O', ''),
#  (appreciation, 'O', ''),
#  (of, 'O', ''),
#  (things, 'O', ''),
#  (beautiful, 'O', ''),
#  (he, 'O', ''),
#  (liked, 'O', ''),
#  (to, 'O', ''),
#  (make, 'O', ''),
#  (gifts, 'O', ''),
#  (of, 'O', ''),
#  (expensively, 'O', ''),
#  (bound, 'O', ''),
#  (books, 'O', ''),
#  (and, 'O', ''),
#  (objects, 'O', ''),
#  (of, 'O', ''),
#  (art, 'O', ''),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (When, 'O', ''),
#  (the, 'O', ''),
#  (Chancellor, 'O', ''),
#  ('s, 'O', ''),
#  (Palace, 'B', 'ORG'),
#  (in, 'O', ''),
#  (Berlin, 'B', 'GPE'),
#  (was, 'O', ''),
#  (being, 'O', ''),
#  (redecorated, 'O', ''),
#  (for, 'O', ''),
#  (him, 'O', ''),
#  (he, 'O', ''),
#  (superintended, 'O', ''),
#  (the, 'O', ''),
#  (work, 'O', ''),
#  (in, 'O', ''),
#  (several, 'O', ''),
#  (modernistic, 'O', ''),
#  (rooms, 'O', ''),
#  (and, 'O', ''),
#  (paid, 'O', ''),
#  (special, 'O', ''),
#  (attention, 'O', ''),
#  (to, 'O', ''),
#  (the, 'O', ''),
#  (installation, 'O', ''),
#  (of, 'O', ''),
#  (Nordic, 'B', 'NORP'),
#  (mythological, 'O', ''),
#  (tapestries, 'O', ''),
#  (depicting, 'O', ''),
#  (Wotan, 'B', 'GPE'),
#  (creating, 'O', ''),
#  (the, 'O', ''),
#  (world, 'O', ''),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (Munich, 'O', ''),
#  (His, 'O', ''),
#  (Favorite, 'B', 'GPE'),
#  (City, 'I', 'GPE'),
#  (
#
#  , 'O', ''),
#  (His, 'O', ''),
#  (Munich, 'B', 'GPE'),
#  (flat, 'O', ''),
#  (,, 'O', ''),
#  (which, 'O', ''),
#  (he, 'O', ''),
#  (redecorated, 'O', ''),
#  (in, 'O', ''),
#  (1935, 'B', 'DATE'),
#  (in, 'O', ''),
#  (his, 'O', ''),
#  (favorite, 'O', ''),
#  (baroque, 'O', ''),
#  (blue, 'O', ''),
#  (,, 'O', ''),
#  (white, 'O', ''),
#  (and, 'O', ''),
#  (gold, 'O', ''),
#  (,, 'O', ''),
#  (was, 'O', ''),
#  (in, 'O', ''),
#  (an, 'O', ''),
#  (unfashionable, 'O', ''),
#  (section, 'O', ''),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (Prinzregentenstrasse, 'B', 'ORG'),
#  (., 'O', ''),
#  (To, 'O', ''),
#  (this, 'O', ''),
#  (flat, 'O', ''),
#  (he, 'O', ''),
#  (would, 'O', ''),
#  (retire, 'O', ''),
#  (when, 'O', ''),
#  (he, 'O', ''),
#  (wanted, 'O', ''),
#  (privacy, 'O', ''),
#  (., 'O', ''),
#  (
#
#  , 'O', ''),
#  (Munich, 'O', ''),
#  (was, 'O', ''),
#  (his, 'O', ''),
#  (favorite, 'O', ''),
#  (city, 'O', ''),
#  (,, 'O', ''),
#  (not, 'O', ''),
#  (only, 'O', ''),
#  (because, 'O', ''),
#  (of, 'O', ''),
#  (its, 'O', ''),
#  (architectural, 'O', ''),
#  (beauty, 'O', ''),
#  (but, 'O', ''),
#  (because, 'O', ''),
#  (it, 'O', ''),
#  (was, 'O', ''),
#  (there, 'O', ''),
#  (that, 'O', ''),
#  (his, 'O', ''),
#  (career, 'O', ''),
#  (was, 'O', ''),
#  (launched, 'O', ''),
#  (., 'O', ''),
#  (The, 'O', ''),
#  (apartment, 'O', ''),
#  (was, 'O', ''),
#  (run, 'O', ''),
#  (by, 'O', ''),
#  (a, 'O', ''),
#  (half, 'O', ''),
#  (-, 'O', ''),
#  (sister, 'O', ''),
#  (,, 'O', ''),
#  (Frau, 'B', 'PERSON'),
#  (Angella, 'I', 'PERSON'),
#  (Raubal, 'I', 'PERSON'),
#  (,, 'O', ''),
#  (who, 'O', ''),
#  (,, 'O', ''),
#  (until, 'O', ''),
#  (her, 'O', ''),
#  (marriage, 'O', ''),
#  (to, 'O', ''),
#  (a, 'O', ''),
#  (Professor, 'O', ''),
#  (Martin, 'B', 'PERSON'),
#  (Hammisch, 'I', 'PERSON'),
#  (,, 'O', ''),
#  (also, 'O', ''),
#  (supervised, 'O', ''),
#  (Haus, 'B', 'PERSON'),
#  (Wachenfeld, 'I', 'PERSON'),
#  (,, 'O', ''),
#  (Hitler, 'B', 'PERSON'),
#  ('s, 'O', ''),
#  (mountain, 'O', ''),
#  (retreat, 'O', ''),
#  (at, 'O', ''),
#  (Berchtesgaden, 'B', 'GPE'),
#  (overlooking, 'O', ''),
#  (a, 'O', ''),
#  (magnificent, 'O', ''),
#  (vista, 'O', ''),
#  (in, 'O', ''),
#  (the, 'O', ''),
#  (Bavarian, 'B', 'NORP'),
#  (Alps, 'B', 'LOC'),
#  (,, 'O', ''),
#  (at, 'O', ''),
#  (a, 'O', ''),
#  (point, 'O', ''),
#  (from, 'O', ''),
#  (which, 'O', ''),
#  (the, 'O', ''),
#  (Fuehrer, 'B', 'ORG'),
#  (could, 'O', ''),
#  (look, 'O', ''),
#  (across, 'O', ''),
#  (into, 'O', ''),
#  (his, 'O', ''),
#  (native, 'O', ''),
#  (Austria, 'B', 'GPE'),
#  (., 'O', ''),
#  (
#
#
#
# , 'O', '')]

# %%
Counter([x.label_ for x in document.ents])
# Out:
# Counter({'DATE': 181,
#          'ORG': 111,
#          'PERSON': 363,
#          'CARDINAL': 60,
#          'NORP': 243,
#          'GPE': 321,
#          'LOC': 29,
#          'EVENT': 12,
#          'WORK_OF_ART': 10,
#          'ORDINAL': 18,
#          'TIME': 13,
#          'PRODUCT': 3,
#          'LAW': 8,
#          'MONEY': 3,
#          'PERCENT': 1,
#          'FAC': 3,
#          'LANGUAGE': 1})

# %%
Counter([x.label_ for x in document.ents]).most_common(3)
# Out:
# [('PERSON', 363), ('GPE', 321), ('NORP', 243)]

# %%
sentences = [x for x in document.sents]
print(sentences[5])
# Out:
# Like Lenin and Mussolini, Hitler came out of the blood and chaos of 1914-18, but of the three he was the strangest phenomenon.

# %%
displacy.render(nlp(str(sentences[5])), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Like
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lenin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mussolini
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hitler
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  came out of the blood and chaos of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1914-18
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , but of the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     three
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  he was the strangest phenomenon.</div></span>

# %% [markdown]
# Using spaCy’s built-in displaCy visualizer, here’s what the above sentence and its dependencies look like:

# %%
displacy.render(nlp(str(sentences[5])), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="a27819af58a04e0f88ce91aa95cbc61d-0" class="displacy" width="2930" height="617.0" direction="ltr" style="max-width: none; height: 617.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Like</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">Lenin</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">Mussolini,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">Hitler</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">came</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">out</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">blood</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">chaos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">1914-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">18,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">but</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">three</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">he</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">strangest</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="2810">phenomenon.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2810">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a27819af58a04e0f88ce91aa95cbc61d-0-0" stroke-width="2px" d="M70,482.0 C70,182.0 635.0,182.0 635.0,482.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a27819af58a04e0f88ce91aa95cbc61d-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,484.0 L62,472.0 78,472.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a27819af58a04e0f88ce91aa95cbc61d-0-1" stroke-width="2px" d="M70,482.0 C70,422.0 135.0,422.0 135.0,482.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a27819af58a04e0f88ce91aa95cbc61d-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M135.0,484.0 L143.0,472.0 127.0,472.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a27819af58a04e0f88ce91aa95cbc61d-0-2" stroke-width="2px" d="M190,482.0 C190,422.0 255.0,422.0 255.0,482.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a27819af58a04e0f88ce91aa95cbc61d-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M255.0,484.0 L263.0,472.0 247.0,472.0" fill="curr

# %%
# as dictionary
'''Like Lenin and Mussolini, Hitler came out of the blood and 
chaos of 1914-18, but of the three he was the strangest phenomenon.'''
dict([(str(x), x.label_) for x in nlp(str(sentences[5])).ents])
# Out:
# {'Lenin': 'PERSON',
#  'Mussolini': 'PERSON',
#  'Hitler': 'PERSON',
#  '1914-18': 'DATE',
#  'three': 'CARDINAL'}
